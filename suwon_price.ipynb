# %% [markdown]
# # 라이브러리 호출

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib as mpl
import plotly.express as px
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import *
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from xgboost import XGBRegressor
import numpy as np
import platform

# %% [markdown]
# # 한글 폰트 설치

# %%
# 단계 1: 폰트 설치

# !apt-get -qq -y install fonts-nanum > /dev/null
font_path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'

font_name = fm.FontProperties(fname=font_path, size=9).get_name()

#fm._rebuild()

fe = fm.FontEntry(
    fname=r'/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf', # ttf 파일이 저장되어 있는 경로
    name='NanumGothic')                        # 이 폰트의 원하는 이름 설정
fm.fontManager.ttflist.insert(0, fe)              # Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 18, 'font.family': 'NanumGothic'}) # 폰트 설

# %% [markdown]
# # 데이터 호출 및 전처리

# %%
# JSON 파일을 읽어서 데이터 프레임으로 변환
df_20220228 = pd.read_json("https://gist.githubusercontent.com/chanho0908/f638455cd0874917692b02d8a9548378/raw/6369d0e9abb6fa0cd3ccef7550b177690b17831f/20220228_suwon_pride_trend")
df_20220324 = pd.read_json("https://gist.githubusercontent.com/chanho0908/f638455cd0874917692b02d8a9548378/raw/6369d0e9abb6fa0cd3ccef7550b177690b17831f/20220324_suwon_pride_trend")
df_20220424 = pd.read_json("https://gist.githubusercontent.com/chanho0908/f638455cd0874917692b02d8a9548378/raw/6369d0e9abb6fa0cd3ccef7550b177690b17831f/20220424_suwon_pride_trend")
df_20220524 = pd.read_json("https://gist.githubusercontent.com/chanho0908/f638455cd0874917692b02d8a9548378/raw/6369d0e9abb6fa0cd3ccef7550b177690b17831f/20220524_suwon_pride_trend")
df_20220624 = pd.read_json("https://gist.githubusercontent.com/chanho0908/f638455cd0874917692b02d8a9548378/raw/6369d0e9abb6fa0cd3ccef7550b177690b17831f/20220624_suwon_pride_trend")
df_20220724 = pd.read_json("https://gist.githubusercontent.com/chanho0908/f638455cd0874917692b02d8a9548378/raw/6369d0e9abb6fa0cd3ccef7550b177690b17831f/20220724_suwon_pride_trend")
df_20220824 = pd.read_json("https://gist.githubusercontent.com/chanho0908/f638455cd0874917692b02d8a9548378/raw/6369d0e9abb6fa0cd3ccef7550b177690b17831f/20220824_suwon_pride_trend")
df_20220926 = pd.read_json("https://gist.githubusercontent.com/chanho0908/f638455cd0874917692b02d8a9548378/raw/6369d0e9abb6fa0cd3ccef7550b177690b17831f/20220926_suwon_pride_trend")
df_20221024 = pd.read_json("https://gist.githubusercontent.com/chanho0908/f638455cd0874917692b02d8a9548378/raw/6369d0e9abb6fa0cd3ccef7550b177690b17831f/20221024_suwon_pride_trend")
df_20221125 = pd.read_json("https://gist.githubusercontent.com/chanho0908/f638455cd0874917692b02d8a9548378/raw/6369d0e9abb6fa0cd3ccef7550b177690b17831f/20221125_suwon_pride_trend")
df_20221227 = pd.read_json("https://gist.githubusercontent.com/chanho0908/f638455cd0874917692b02d8a9548378/raw/6369d0e9abb6fa0cd3ccef7550b177690b17831f/20221227_suwon_pride_trend")
df_20220125 = pd.read_json("https://gist.githubusercontent.com/chanho0908/f638455cd0874917692b02d8a9548378/raw/6369d0e9abb6fa0cd3ccef7550b177690b17831f/20230125_suwon_pride_trend")
df_20230228 = pd.read_json("https://gist.githubusercontent.com/chanho0908/f638455cd0874917692b02d8a9548378/raw/6369d0e9abb6fa0cd3ccef7550b177690b17831f/20230228_suwon_pride_trend")
df_20230328 = pd.read_json("https://gist.githubusercontent.com/chanho0908/f638455cd0874917692b02d8a9548378/raw/6369d0e9abb6fa0cd3ccef7550b177690b17831f/20230328_suwon_pride_trend")
df_20230428 = pd.read_json("https://gist.githubusercontent.com/chanho0908/f638455cd0874917692b02d8a9548378/raw/6369d0e9abb6fa0cd3ccef7550b177690b17831f/20230428_suwon_pride_trend")
df_20230526 = pd.read_json("https://gist.githubusercontent.com/chanho0908/f638455cd0874917692b02d8a9548378/raw/6369d0e9abb6fa0cd3ccef7550b177690b17831f/20230526_suwon_pride_trend")
df_20230626 = pd.read_json("https://gist.githubusercontent.com/chanho0908/f638455cd0874917692b02d8a9548378/raw/6369d0e9abb6fa0cd3ccef7550b177690b17831f/20230626_suwon_pride_trend")
df_20230726 = pd.read_json("https://gist.githubusercontent.com/chanho0908/f638455cd0874917692b02d8a9548378/raw/c88497cfd2fe881fa08c0850b94311da0f555eab/20230726_suwon_pride_trend")
df_20230825 = pd.read_json("https://gist.githubusercontent.com/chanho0908/f638455cd0874917692b02d8a9548378/raw/6369d0e9abb6fa0cd3ccef7550b177690b17831f/20230825_suwon_pride_trend")
df_20230926 = pd.read_json("https://gist.githubusercontent.com/chanho0908/f638455cd0874917692b02d8a9548378/raw/6369d0e9abb6fa0cd3ccef7550b177690b17831f/20230926_suwon_pride_trend")

# 데이터 프레임 리스트
dfs = [
    df_20220228, df_20220324, df_20220424, df_20220524, df_20220624, df_20220724, df_20220824, df_20220926, df_20221024, df_20221125,
    df_20221227, df_20220125, df_20230228, df_20230328, df_20230428, df_20230526, df_20230626, df_20230726, df_20230825, df_20230926
]

# 데이터 프레임 합치기
firstDataFrame = pd.concat(dfs, ignore_index=True)

# 필요없는 열 삭제
firstDataFrame.drop(['데이터기준일자', '규격 및 단위'], axis=1, inplace=True)

# Json에서 값이 ""일 경우 판다스는 누락된 값이 아닌 빈 문자열로 처리
# 물가동향 열에서 빈 문자열을 NaN으로 변환
firstDataFrame['물가동향'].replace('', pd.NA, inplace=True)

# 숫자로 변환이 불가능한 값은 NaN으로 처리
firstDataFrame['물가동향'] = pd.to_numeric(firstDataFrame['물가동향'], errors='coerce')

# NaN 값을 가진 행을 삭제
df_natnan = firstDataFrame.dropna(subset=['물가동향'])

# 물가 동향의 값이 빈 경우 확인
no_values_count = df_natnan['물가동향'].isna().sum()
#print('물가 동향의 값이 비어있는 경우: ', no_values_count)

# 물가 동향의 값이 데이터 미존재인 경우 확인
noData = (df_natnan['물가동향'] == '데이터미존재').sum()
#print('물가 동향의 값이 데이터미존재인 경우: ', noData)

# '기준일' 열을 datetime 형식으로 변환
df_natnan['기준일'] = pd.to_datetime(df_natnan['기준일'])

# '기준일' 열을 월까지만 보여줌
df_natnan['기준일'] = df_natnan['기준일'].dt.strftime('%Y-%m')

'''
현재 데이터는 한 달 동안 한 가지 품목의 물가에 대해서 날짜에 따라 여러번 작성됨
한 달 동안 가장 높은 가격을 기록한 날만 남기고 나머지 데이터는 삭제
'''

# 데이터프레임을 '기준일', '품목' 및 '물가동향' 열을 기준으로 그룹화
# 각 그룹에 대해 '물가동향' 열에서 최대 값을 가지는 행을 선택
grouped_df = df_natnan.groupby(['기준일', '품목'])['물가동향'].idxmax()

# 선택한 행의 인덱스를 사용하여 원래 데이터프레임에서 해당 행을 추출하여 새로운 데이터프레임을 생성
mainDataFrame = df_natnan.loc[grouped_df]

#삭제된 행 확인
#deleted_rows = mainDataFrame[~mainDataFrame.index.isin(filtered_df.index)]
#deleted_rows

mainDataFrame
# Out:
# <ipython-input-104-c85ba7ec9938>:54: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-104-c85ba7ec9938>:57: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            기준일 시군구명               구분        품목      물가동향
# 351    2022-02  권선구      개인서비스요금(기타)   PC방 이용료    1144.0
# 561    2022-02  권선구  개인서비스요금(외식비-한식)       갈비탕   12700.0
# 120    2022-02  권선구           수산물(4)        갈치   10133.0
# 371    2022-02  권선구           수산물(4)       고등어    4122.0
# 533    2022-02  장안구      개인서비스요금(기타)  골프연습장이용료  360000.0
# ...        ...  ...              ...       ...       ...
# 14206  2023-09  권선구     개인서비스요금(외식비)       탕수육   23950.0
# 14359  2023-09  영통구      개인서비스요금(기타)     택배수수료    7878.0
# 14520  2023-09  팔달구     개인서비스요금(외식비)        피자   17343.0
# 14333  2023-09  영통구     개인서비스요금(외식비)       햄버거    4578.0
# 14618  2023-09  영통구    생필품 요금(농산물 8)        호박    2438.0
#
# [1223 rows x 5 columns]

# %% [markdown]
# # 한식 데이터 분석

# %%
# 한식만 추출
korean_food = mainDataFrame[mainDataFrame['구분'].str.contains('한식')].copy()
k_food_list = korean_food['품목'].drop_duplicates().tolist()
df_kfood = mainDataFrame[mainDataFrame['품목'].isin(k_food_list)]

# DataFrame을 '품목' 컬럼으로 그룹핑 하고, '물가동향' 컬럼에 12개월(12개월, 즉 1년을 나타냄)
# 로 df_kfood 변화율( ) 함수를 적용하여 전년 대비 인플레이션을 계산
df_kfood['전년동월대비'] = df_kfood.groupby('품목')['물가동향'].pct_change(periods=12)
df_kfood.dropna(inplace=True)

# 그래프 그리기
fig = px.bar(
    df_kfood,
    x='전년동월대비',
    y='품목',
    text='전년동월대비',
    orientation='h',
    color='품목',
    color_discrete_sequence=px.colors.qualitative.Set3,
    hover_data=['기준일']  # Add '기준일' to hover data
)

fig.update_traces(
    texttemplate='%{text:.1%}',
    textposition='outside',  # 텍스트 형식 및 위치 설정
    hovertemplate='월: %{customdata[0]}<br>전년동월대비: %{x:.1%}<extra></extra>'  # Custom hover template
)

# 그래프 크기 조절
fig.update_layout(
    title=dict(
        text='한식 전월 동원 대비 물가 상승률',
        x=0.5,  # Center the title
        y=0.95,  # Adjust the vertical position of the title
        xanchor='center',
        yanchor='top',
    ),
    width=1300,
    height=600
)

fig.show()
# Out:
# <ipython-input-105-bf9bddd9ea8c>:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-105-bf9bddd9ea8c>:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="369b3ba8-6574-4e8f-8478-ba910a57a9ad" class="plotly-graph-div" style="height:600px; width:1300px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById
yaxis":"y","type":"bar","texttemplate":"%{text:.1%}"},{"alignmentgroup":"True","customdata":[["2023-02"],["2023-03"],["2023-04"],["2023-05"],["2023-06"],["2023-07"],["2023-08"],["2023-09"]],"hovertemplate":"\uc6d4: %{customdata[0]}\u003cbr\u003e\uc804\ub144\ub3d9\uc6d4\ub300\ube44: %{x: ...

# %% [markdown]
# # 소고기 물가 상승률

# %%
df_beef = mainDataFrame[mainDataFrame['품목'] == '쇠고기']
df_beef = df_beef[df_beef['기준일'].str.contains('2023')]
df_beef['전년동월대비'] = df_beef['물가동향']
#df_beef.dropna(inplace=True)

# 시각화
plt.figure(figsize=(18, 6))

# 물가 동향 선 그래프
ax = sns.lineplot(data=df_beef, x='기준일', y='물가동향', marker='o', label='물가 동향')

# 그래프 타이틀 및 레이블 설정
plt.title('소고기 물가 상승률', fontsize=18)
plt.xlabel('기준일', fontsize=14)
plt.ylabel('물가 동향', fontsize=14)

#각 데이터 포인트에 숫자로 된 라벨 추가
for i, txt in enumerate(df_beef['전년동월대비']):
   ax.text(df_beef['기준일'].iloc[i], df_beef['물가동향'].iloc[i], txt, ha='center', va='bottom')

# 그래프 표시
plt.show()

# %% [markdown]
# # 소고기를 사용하는 음식 물가 분석

# %%
df_beef = mainDataFrame[mainDataFrame['품목'] == '쇠고기']
df_use_beef_items = ['갈비탕', '불고기', '설렁탕']

# 품목이 df_use_beef_items에 있는 데이터만 필터링
df_selected_beef_items = mainDataFrame[mainDataFrame['품목'].isin(df_use_beef_items)].copy()

# 전년동월대비 물가 상승률 계산
df_selected_beef_items['전년동월대비'] = df_selected_beef_items.groupby('품목')['물가동향'].pct_change(periods=12)
df_selected_beef_items.dropna(inplace=True)

colors = sns.color_palette("husl", len(df_use_beef_items))
# 그래프 그리기 - subplot으로 나눠서 표시
fig, axes = plt.subplots(3, 1, figsize=(8, 13))  # One row, three columns

# Iterate through each item and plot it on a separate subplot
for i, (item, color) in enumerate(zip(df_use_beef_items, colors)):
    # Check if the data for the item is not empty before creating the line plot
    if not df_selected_beef_items[df_selected_beef_items['품목'] == item].empty:
        sns.lineplot(data=df_selected_beef_items[df_selected_beef_items['품목'] == item],
                     x='기준일', y='전년동월대비', ax=axes[i], color=color, marker='o', label=item)
        axes[i].set_title(item)
        axes[i].set_xlabel('기준일')
        axes[i].set_ylabel('전년동월대비 물가 상승률')
        axes[i].legend()

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # 수산물 전월 대비 물가 동향

# %%
df_seafood = mainDataFrame[mainDataFrame['구분'].str.contains('수산물')].copy()
seafood_list = df_seafood['품목'].drop_duplicates().tolist()
seafood = mainDataFrame[mainDataFrame['품목'].isin(seafood_list)]

# '품목'을 기준으로 그룹화하고 '물가동향' 열에서 전년동월대비 물가 상승 지수 계산
df_seafood['전년동월대비'] = df_seafood.groupby('품목')['물가동향'].pct_change(periods=12)
df_seafood.dropna(inplace=True)

# 결과 확인
# '고등어' 품목 선택
df_mackerel = df_seafood[df_seafood['품목'] == '고등어']
# '갈치' 품목 선택
df_cutlassfish = df_seafood[df_seafood['품목'] == '갈치']
# '동태' 품목 선택
df_dongtae = df_seafood[df_seafood['품목'] == '동태']
# '오징어' 품목 선택
df_squid = df_seafood[df_seafood['품목'] == '오징어']

# 그래프 그리기
plt.figure(figsize=(15, 7))
plt.plot(df_mackerel['기준일'], df_mackerel['전년동월대비'], label='고등어', marker='o', linestyle='-')
plt.plot(df_cutlassfish['기준일'], df_cutlassfish['전년동월대비'], label='갈치', marker='o', linestyle='-')
plt.plot(df_dongtae['기준일'], df_dongtae['전년동월대비'], label='동태', marker='o', linestyle='-')
plt.plot(df_squid['기준일'], df_squid['전년동월대비'], label='오징어', marker='o', linestyle='-')

# 차트에 전년동월대비가 가장 높은 지점에 해당하는 값을 추가
max_value = df_seafood.loc[df_seafood['전년동월대비'].idxmax()]
plt.annotate(f'Max: {max_value["전년동월대비"]*0.01:.2%}\n{max_value["기준일"]}',
             xy=(max_value['기준일'], max_value['전년동월대비']),
             xytext=(max_value['기준일'], max_value['전년동월대비'] + 0.1),  # 위치 조정
             arrowprops=dict(facecolor='red', shrink=0.05),  # 화살표 추가
             )

# Marker 위에 값 표시 (최소값)
for i, txt in enumerate(df_seafood[df_seafood['전년동월대비'] == df_seafood['전년동월대비'].min()]['전년동월대비']):
    plt.text(df_seafood[df_seafood['전년동월대비'] == df_seafood['전년동월대비'].min()]['기준일'].iloc[i],
             txt + 0.05, f'Min: {txt*0.01:.2%}', ha='center', va='bottom', color='green')

plt.title('수산물 전년동월대비 물가 동향(%)', loc='left', fontsize=20)
plt.xlabel('기준일')
plt.ylabel('전년동월대비')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()

# 그래프 표시
plt.show()
# Out:
# <ipython-input-108-6836f6ce8907>:45: UserWarning:
#
# Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning:
#
# Glyph 8722 (\N{MINUS SIGN}) missing from current font.

# %% [markdown]
# # 치킨 데이터 분석

# %%
# 치킨 데이터만 분리
df_chicken = mainDataFrame[mainDataFrame['품목'] == '치킨'].copy()

# 전년도 동월 가격과 비교
df_chicken['전년동월대비'] = df_chicken['물가동향'].pct_change(periods=12)
df_chicken.dropna(inplace=True)

# 시각화할 데이터만 분리
df_chicken = df_chicken[['기준일', '전년동월대비']]

fig = px.bar(df_chicken, x='기준일', y='전년동월대비', color='기준일',
             color_continuous_scale=px.colors.sequential.Oranges,
             title='전년 동월 대비 치킨 상승률',
             )
fig.update_layout(width=900)
'''
데이터프레임의 각 행을 반복하면서 플롯에 주석을 추가
  x : 주석의 x 좌표
  y : 주석의 y 좌표
  showarrow : 화살표 표시
  arrowhead : 화살표 머리
'''
for i, row in df_chicken.iterrows():
    fig.add_annotation(
        x=row['기준일'],
        y=row['전년동월대비'],
        text=f"{row['전년동월대비']:.2%}",
        showarrow=True,
        arrowhead=2,
        arrowcolor="black",
    )

# 제목 가운데로 옮기기
fig.update_layout(
    title=dict(
        text='전년 동월 대비 치킨 상승률',
        x=0.5,
        font=dict(size=24)  # font size 설정
    )
)

fig.update_xaxes(type='category')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b66120f1-9035-4f89-81cd-942e3e6fd280" class="plotly-graph-div" style="height:525px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b66120f1-9035-4f89-81cd-942e3e6fd280")) {                    Plotly.newPlot(                        "b66120f1-9035-4f89-81cd-942e3e6fd280",                        [{"alignmentgroup":"True","hovertemplate":"\uae30\uc900\uc77c=%{x}\u003cbr\u003e\uc804\ub144\ub3d9\uc6d4\ub300\ube44=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2023-02","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"2023-02","offsetgroup":"2023-02","orientation":"v","showlegend":true,"textposition":"auto","x":["2023-02"],"xaxis":"x","y":[0.1003058103975536],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"\uae30\uc900\uc77c=%{x}\u003cbr\u003e\uc804\ub144\ub3d9\uc6d4\ub300\ube44=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2023-03","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"2023-03","offsetgroup":"2023-03","orientation":"v","showlegend":true,"textposition":"auto","x":["2023-03"],"xaxis":"x","y":[0.08195718654434248],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"\uae30\uc900\uc77c=%{x}\u003cbr\u003e\uc804\ub144\ub3d9\uc6d4\ub300\ube44=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2023-04","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"2023-04","offsetgroup":"2023-04","orientation":"v","showlegend":true,"textposition":"auto","x":["2023-04"],"xaxis":"x","y":[0.06952841596130588],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"\uae30\uc900\uc77c=%{x}\u003cbr\u003e\uc804\ub144\ub3d9\uc6d4\ub300\ube44=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2023-05","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"2023-05","offsetgroup":"2023-05","orientation":"v","showlegend":true,"textposition":"auto","x":["2023-05"],"xaxis":"x","y":[0.06488095238095237],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"\uae30\uc900\uc77c=%{x}\u003cbr\u003e\uc804\ub144\ub3d9\uc6d4\ub300\ube44=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2023-06","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"2023-06","offsetgroup":"2023-06","orientation":"v","showlegend":true,"textposition":"auto","x":["2023-06"],"xaxis":"x","y":[0.06809384164222876],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"\uae30\uc900\uc77c=%{x}\u003cbr\u003e\uc804\ub144\ub3d9\uc6d4\ub300\ube44=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2023-07","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"2023-07","offsetgroup":"2023-07","orientation":"v","showlegend":true,"textposition":"auto","x":["2023-07"],"xaxis":"x","y":[0.008807985907222537],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"\uae30\uc900\uc77c=%{x}\u003cbr\u003e\uc804\ub144\ub3d9\uc6d4\ub300\ube44=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2023-08","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"2023-08","offsetgroup":"2023-08","orientation":"v","showlegend":true,"textposition":"auto","x":["2023-08"],"xaxis":"x","y":[0.02025462962962954],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"\uae30\uc900\uc77c=%{x}\u003cbr\u003e\uc804\ub144\ub3d9\uc6d4\ub300\ube44=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2023-09","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"2023-09","offsetgroup":"2023-09","orientation":"v","showlegend":true,"textposition":"auto","x":["2023-09"],"xaxis":"x","y":[0.040162980209546006],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour"," ...

# %% [markdown]
# # 회귀 알고리즘을 사용한 치킨 물가 예측

# %%
# 데이터 분리
reg_df_chicken = mainDataFrame[mainDataFrame['품목'] == '치킨'].copy()
reg_df_chicken = reg_df_chicken[['기준일', '물가동향']]
reg_df_chicken['기준일'] = pd.to_datetime(reg_df_chicken['기준일'])
reg_df_chicken['Month'] = reg_df_chicken['기준일'].dt.month
reg_df_chicken = reg_df_chicken[['Month', '물가동향']]
reg_df_chicken
# Out:
#        Month     물가동향
# 144        2  16350.0
# 888        3  16350.0
# 1632       4  16540.0
# 2624       5  16800.0
# 3120       6  17050.0
# 4422       7  17030.0
# 5166       8  17280.0
# 5910       9  17180.0
# 6096      10  17450.0
# 6840      11  17450.0
# 8138      12  17430.0
# 8571       1  17690.0
# 9315       2  17990.0
# 10059      3  17690.0
# 10803      4  17690.0
# 11299      5  17890.0
# 12043      6  18211.0
# 13345      7  17180.0
# 13903      8  17630.0
# 14585      9  17870.0

# %%
def get_model_cv_prediction(model, X_data, y_target):
    neg_mse_scores = cross_val_score(model, X_data, y_target, scoring="neg_mean_squared_error", cv=7)
    rmse_scores = np.sqrt(-1 * neg_mse_scores)
    avg_rmse = np.mean(rmse_scores)
    print('##### ', model.__class__.__name__, ' #####')
    print(' 7 교차 검증의 평균 RMSE : {0:.3f} '.format(avg_rmse))

def get_cv_predictions(model, X_data, y_target):
    predicted = cross_val_predict(model, X_data, y_target, cv=7)
    return predicted

# %%
y_target = reg_df_chicken['물가동향']
X_data = reg_df_chicken[['Month']]

X_train, X_test, y_train, y_test = train_test_split(X_data, y_target, test_size=0.3, random_state=42)

ada_reg = AdaBoostRegressor()
xgb_reg = XGBRegressor()

# 트리 기반의 회귀 모델을 반복하면서 평가 수행
models = [ada_reg, xgb_reg]
for model in models:
    get_model_cv_prediction(model, X_data, y_target)
# Out:
# #####  AdaBoostRegressor  #####
#  7 교차 검증의 평균 RMSE : 812.287
# #####  XGBRegressor  #####
#  7 교차 검증의 평균 RMSE : 855.070

# %%
# 데이터 학습
ada_reg.fit(X_train, y_train)
xgb_reg.fit(X_train, y_train)

ada_pred_cv = get_cv_predictions(ada_reg, X_data, y_target)
xgb_pred_cv = get_cv_predictions(xgb_reg, X_data, y_target)

results_df_cv = pd.DataFrame({
    'Actual': y_target,
    'AdaBoost Predicted (CV)': ada_pred_cv,
    'XGBoost Predicted (CV)': xgb_pred_cv,
    'Month': reg_df_chicken['Month'].astype(str)
})

# 시각화
sns.set(color_codes=True)

plt.figure(figsize=(16, 6))

for i, model_name in enumerate(['AdaBoost', 'XGBoost']):
    plt.subplot(1, 2, i+1)
    sns.lineplot(x='Month', y='Actual', data=results_df_cv, label='DATA', linewidth=2.5)
    sns.lineplot(x='Month', y=f'{model_name} Predicted (CV)', data=results_df_cv, label='PREDICT', linewidth=2.5)
    plt.title(model_name)
    plt.xlabel('Month')
    plt.ylabel('Price')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # MODEL : DecisionTreeRegressor

# %%
# 데이터 전처리
df_chicken = mainDataFrame[mainDataFrame['품목'] == '치킨'].copy()
df_chicken['기준일'] = pd.to_datetime(df_chicken['기준일'])
df_chicken = df_chicken.sort_values('기준일')

# 특성 선택
X = df_chicken['기준일'].dt.month.values.reshape(-1, 1)
y = df_chicken['물가동향'].values

# 훈련 및 테스트 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# 결정 트리 모델 학습
model = DecisionTreeRegressor(max_depth=10)
model.fit(X_train, y_train)

# 테스트 데이터에 대한 예측
y_pred = model.predict(X_test)

# 평가
mse = mean_squared_error(y_test, y_pred)
# RMSE 계산 및 출력
rmse = np.sqrt(mse)
print(f'Root Mean Squared Error (RMSE): {rmse}')

# 예측 결과 시각화
plt.figure(figsize=(17, 6))
plt.scatter(df_chicken['기준일'], df_chicken['물가동향'], label='DATA')
plt.plot(df_chicken['기준일'], model.predict(X), color='red', label='PREDICT')
plt.xlabel('MONTH')
plt.ylabel('PRICE')
plt.legend()
plt.show()
# Out:
# Root Mean Squared Error (RMSE): 394.176356470045

# %% [markdown]
# # MODEL : LinearRegression(선형 회귀)

# %%
# 데이터 전처리
df_chicken = mainDataFrame[mainDataFrame['품목'] == '치킨'].copy()
df_chicken['기준일'] = pd.to_datetime(df_chicken['기준일'])
df_chicken = df_chicken.sort_values('기준일')

# 특성 선택
X = df_chicken['기준일'].dt.month.values.reshape(-1, 1)
y = df_chicken['물가동향'].values

# 훈련 및 테스트 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# 회귀 모델 학습
model = LinearRegression()
model.fit(X_train, y_train)

# 테스트 데이터에 대한 예측
y_pred = model.predict(X_test)

# 평가
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(f'Root Mean Squared Error (RMSE) on Test Set: {rmse}')

# 예측 결과 시각화
plt.figure(figsize=(17, 6))
plt.scatter(df_chicken['기준일'], df_chicken['물가동향'], label='DATA')
plt.plot(df_chicken['기준일'], model.predict(X), color='red', label='PREDICT')
plt.xlabel('Month')
plt.ylabel('PRICE')
plt.legend()
plt.show()
# Out:
# Root Mean Squared Error (RMSE) on Test Set: 300.550782374349

# %% [markdown]
# # 네이버 API 크롤링

# %%
# import os
# import sys
# import urllib.request
# import datetime
# import time
# import json

# client_id = '0LHQM4VX_MQM6JfkXofa'
# client_secret = 'OcPgqpswCg'


# #[CODE 1]
# #1. 검색어 지정
# def getRequestUrl(url):
#   req = urllib.request.Request(url) # 매개변수로 받은 url에 대한 요청을 보낼 객체를 생성
#   req.add_header("X-Naver-Client-Id", client_id) # API를 사용하기 위한 Client ID와 Client Secret 코드를 요청 객체 헤드에 추가
#   req.add_header("X-Naver-Client-Secret", client_secret)

#   try:
#       response = urllib.request.urlopen(req) # 요청 객체를 보내고 그에 대한 응답을 받아 response 객체에 저장
#       if response.getcode() == 200: # 정상 처리
#           print ("[%s] Url Request Success" % datetime.datetime.now()) # 정상 처리 메시지 출력
#           return response.read().decode('utf-8') # utf-8 형식으로 디코딩 후 반환
#   except Exception as e:
#       print(e)
#       print("[%s] Error for URL : %s" % (datetime.datetime.now(), url))
#       return None

# # 2. 네이버 뉴스 검색
#     #[CODE 2]
# def getNaverSearch(node, srcText, start, display):
#   base = "https://openapi.naver.com/v1/search"
#   node = "/%s.json" % node
#   parameters = "?query=%s&start=%s&display=%s" % (urllib.parse.quote(srcText), start, display)

#   url = base + node + parameters # 네이버 검색 API 정보에 따라 요청 URL을 구성
#   responseDecode = getRequestUrl(url)   #[CODE 1]

#   if (responseDecode == None):
#       return None
#   else:
#       return json.loads(responseDecode) # 서버에서 받은 JSON 형태의 응답 객체를 파이썬 객체로 로드하여 반환

# #[CODE 3]
# def getPostData(post, jsonResult, cnt):
#     title = post['title']
#     description = post['description']
#     org_link = post['originallink']
#     link = post['link']

#     pDate = datetime.datetime.strptime(post['pubDate'],  '%a, %d %b %Y %H:%M:%S +0900')
#     pDate = pDate.strftime('%Y-%m-%d %H:%M:%S')

#     jsonResult.append({'cnt':cnt, 'title':title, 'description': description,
# 'org_link':org_link,   'link': org_link,   'pDate':pDate})
#     return

# #[CODE 0]
# def main():
#     node = 'news'   # 크롤링 할 대상
#     srcText = input('검색어를 입력하세요: ')
#     cnt = 0
#     jsonResult = []

#     jsonResponse = getNaverSearch(node, srcText, 1, 100)  #[CODE 2]
#     total = jsonResponse['total']

#     while ((jsonResponse != None) and (jsonResponse['display'] != 0)):
#         for post in jsonResponse['items']:
#             cnt += 1
#             getPostData(post, jsonResult, cnt)  #[CODE 3]

#         start = jsonResponse['start'] + jsonResponse['display']
#         jsonResponse = getNaverSearch(node, srcText, start, 100)  #[CODE 2]

#     print('전체 검색 : %d 건' %total)

#     with open('%s_naver_%s.json' % (srcText, node), 'w', encoding='utf8') as outfile:
#         jsonFile = json.dumps(jsonResult,  indent=4, sort_keys=True,  ensure_ascii=False)

#         outfile.write(jsonFile)

#     print("가져온 데이터 : %d 건" %(cnt))
#     print ('%s_naver_%s.json SAVED' % (srcText, node))

# if __name__ == '__main__':
#     main()

# %%
df_crawling = pd.read_json('/content/치킨 물가_naver_news.json')
df_crawling = df_crawling.drop(['link', 'org_link'], axis=1)
df_crawling.head()
# Out:
#    cnt                                        description  \
# 0    1  간단하게 해먹을 수 있는 걸로 해서 자주 이용하고 있어요.&quot; 지난달 외식<...
# 1    2  햄버거·피자·<b>치킨</b> 등 외식 메뉴 5개 품목, 우유·빵·라면·아이스크림 ...
# 2    3  슈링크플레이션이란, 양을 줄인다는 뜻의 슈링크(shrink)와 <b>물가</b> 상...
# 3    4  가격 인상한 교촌 3분기 매출 10% 감소 피자알볼로·피자헛 적자 전환 신세계푸드 ...
# 4    5  사진=홈플러스 G밸리뉴스 심영범 기자= 연이어 오르는 <b>물가</b>에 소비자들의...
#
#                  pDate                                             title
# 0  2023-11-25 19:25:00     피자·<b>치킨</b> 집에서 '뚝딱'…고<b>물가</b>에 냉동식품 시장 급성장
# 1  2023-11-25 09:02:00                          소비자 눈 속이는 기업들의 ‘꼼수’ 가격인상
# 2  2023-11-25 08:12:00                     정부, 식품업계 공공연한 '슈링크플레이션' 단속 예고
# 3  2023-11-25 06:03:00  “이제 <b>치킨</b>·피자도 냉동으로”… 고<b>물가</b>에 배달 지고 냉동 뜬다
# 4  2023-11-24 15:30:00                                  유통가, 가성비에 사활 걸었다

# %% [markdown]
# # 워드 클라우딩

# %% [markdown]
# ## KoNLPy library 설치

# %%
# %%bash
# apt-get update
# apt-get install g++ openjdk-8-jdk pythondev
# python3-dev
# pip3 install JPype1
# pip3 install konlpy
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# Requirement already satisfied: JPype1 in /usr/local/lib/python3.10/dist-packages (1.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1) (23.2)
# Requirement already satisfied: konlpy in /usr/local/lib/python3.10/dist-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.4.1)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.3)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (23.2)
# E: Unable to locate package pythondev
# bash: line 3: python3-dev: command not found

# %% [markdown]
# ## 라이브러리 import

# %%
import json
import re

from konlpy.tag import Okt
from PIL import Image
from collections import Counter

import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
from wordcloud import WordCloud

# %% [markdown]
# ## 파일 읽기

# %%
inputFileName = '/content/수원시 물가_naver_news'
data = json.loads(open(inputFileName+'.json', 'r', encoding='utf-8').read())
data #출력하여 내용 확인
# Out:
# [{'cnt': 1,
#   'description': "공원, <b>물가</b>(水)와 가까운 '공세권', '수세권'이라는 입지적 특성으로 시장에서 탄탄한 수요를 갖추고 있던... 광교호수공원 인근에 위치한 <b>수원시</b> 영통구 원천동 광교중흥S클래스의 경우 전용 84B㎡가 지난 9월 15억3... ",
#   'link': 'http://www.gpkorea.com/news/articleView.html?idxno=107610',
#   'org_link': 'http://www.gpkorea.com/news/articleView.html?idxno=107610',
#   'pDate': '2023-11-24 09:26:00',
#   'title': "푸른 녹지와 호수 품은 아파트 '힐스테이트 수원파크포레로'"},
#  {'cnt': 2,
#   'description': "경기도 <b>수원시</b> 권선구 수원메쎄에서 21일 열린 '경기여성 JOB 페스타 2023'을 찾은 구직자들이 이력서를... 이어 ▶<b>물가</b> 급등에 따른 취업준비 비용 부담 증가(13.1%) 등의 순으로 답했다. 대학생 30.3%는 올해 대졸... ",
#   'link': 'http://www.newsian.co.kr/news/articleView.html?idxno=65506',
#   'org_link': 'http://www.newsian.co.kr/news/articleView.html?idxno=65506',
#   'pDate': '2023-11-22 10:36:00',
#   'title': '올해 대학 졸업생 절반 &quot;취업 어려울 것&quot; 우울한 전망'},
#  {'cnt': 3,
#   'description': '홍성걸 국민대 행정학과 교수는 “공사 기간 <b>물가</b> 상승과 설계 변경 등으로 실제 비용은 예상보다 20~30% 더... <b>수원시</b>가 사업비를 20조원가량으로 추산한 대규모 사업인데 이 역시 예타 면제가 포함됐다. 민주당은... ',
#   'link': 'https://www.joongang.co.kr/article/25209115',
#   'org_link': 'https://www.joongang.co.kr/article/25209115',
#   'pDate': '2023-11-22 05:00:00',
#   'title': '6조 드는 달빛철도, 2분 빨리 가려고 5조 더 쓰자는 여야'},
#  {'cnt': 4,
#   'description': '5%), <b>수원시</b>(1.5%), 수성구(1.3%), 성남시(1.3%), 용산구·고양시(1.2%), 종로구(1.1%), 강릉시·강서구·관악구... 그 다음은 <b>물가</b>안정(21.5%), 일자리 창출(8.3%), 사회양극화 해소(8.1%), 저출산 해결(7.9%), 복지확대(6.0... ',
#   'link': 'https://www.dailysportshankook.co.kr/news/articleView.html?idxno=315731',
#   'org_link': 'https://www.dailysportshankook.co.kr/news/articleView.html?idxno=315731',
#   'pDate': '2023-11-21 14:26:00',
#   'title': "행복의 가장 중요한 척도는 '건강'…경제력‧가족 순"},
#  {'cnt': 5,
#   'description': "공원, <b>물가</b>(水)와 가까운 '공세권', '수세권'이라는 입지적 특성으로 시장에서 탄탄한 수요를 갖추고 있던... 광교호수공원 인근에 위치한 <b>수원시</b> 영통구 원천동 광교중흥S클래스의 경우 전용 84B㎡가 지난 9월 15억3... ",
#   'link': 'https://www.dt.co.kr/contents.html?article_no=2023112102109923088001&ref=naver',
#   'org_link': 'https://www.dt.co.kr/contents.html?article_no=2023112102109923088001&ref=naver',
#   'pDate': '2023-11-21 13:55:00',
#   'title': '공원&amp;수변 품은 아파트… `억` 소리 나는 차이 눈길'},
#  {'cnt': 6,
#   'description': "한편, 이날 퀴즈쇼에서는 <b>물가</b> 상승으로 식당의 '이것' 역시 가격이 올랐다고 문제가 출제됐다. 정답은... 이후 퀴즈에는 <b>수원시</b>에 위치한 '세계화장실협회'가 나오기도. 해당 협회는 개발도상국에 화장실을 보급하고... ",
#   'link': 'https://www.xportsnews.com/article/1796302',
#   'org_link': 'https://www.xportsnews.com/article/1796302',
#   'pDate': '2023-11-21 13:51:00',
#   'title': '박명수 &quot;DJ 많이 배출했다…키워줬는데 연락 안 해&quot; (라디오쇼)[종합]'},
#  {'cnt': 7,
#   'description': '경기 <b>수원시</b> 농산물도매시장을 찾아 배추, 무 등 김장철 주요 농산물 반입 상황과 가격 동향을 점검했다고 밝혔다. 한 차관은 농산물도매시장 관계자들과 만나 김장철 소비자 장바구니 <b>물가</b> 부담 완화를 위해 원활한... ',
#   'link': 'https://www.dailysportshankook.co.kr/news/articleView.html?idxno=315617',
#   'org_link': 'https://www.dailysportshankook.co.kr/news/articleView.html?idxno=315617',
#   'pDate': '2023-11-19 15:50:00',
#   'title': '농식품부, 김장철 주요 농산물 수급 점검'},
#  {'cnt': 8,
#   'description': '김용환 <b>수원시</b>지회장은 &quot;올해는 예산 부족으로 더 많은 분들에게 지원을 하지 못해 아쉽다. 내년에는 더 많은 분들과 마음을 나눌 수 있도록 노력하겠다. 김장철에 높은 <b>물가</b>와 겨울 추위에 조금이나마 따뜻한 위안이... ',
#   'link': 'http://www.joongboo.com/news/articleView.html?idxno=363621542',
#   'org_link': 'http://www.joongboo.com/news/articleView.html?idxno=363621542',
#   'pDate': '2023-11-19 15:28:00',
#   'title': "대한민국고엽제전우회 경기도지부 <b>수원시</b>지회, '2023년 김장김치 나눔' 행사"},
#  {'cnt': 9,
#   'description': '농림축산식품부는 한훈 차관이 <b>수원시</b> 농산물도매시장을 방문해 김장철 주요 농산물 반입물량 상황과... 그러면서 도매시장에서도 김장철 소비자 장바구니 <b>물가</b>부담 완화를 위해 산지의 농산물 수집 강화와 원활한... ',
#   'link': 'http://www.joongboo.com/news/articleView.html?idxno=
input=1195m',
#   'org_link': 'https://www.yna.co.kr/view/AKR20231117078200030?input=1195m',
#   'pDate': '2023-11-17 16:30:00',
#   'title': '농식품부, 김장채소 수급 점검…차관 &quot;가격동향 상시 확인&quot;'},
#  {'cnt': 16,
#   'description': '한훈 농림축산식품부 차관은 17일 &quot;도매시장에서도 김장철 소비자 장바구니 <b>물가</b>부담 완화를 위해 산지의 농산물 수집 강화와 원활한 유통거래에 노력해 달라&quot;고 말했다. 한 차관은 이날 경기 <b>수원시</b> 농산물도매시장을... ',
#   'link': 'https://www.news1.kr/articles/5234643',
#   'org_link': 'https://www.news1.kr/articles/5234643',
#   'pDate': '2023-11-17 16:30:00',
#   'title': '한훈 농식품부 차관 &quot;도매시장도 <b>물가</b>안정 위해 노력해 달라&quot;'},
#  {'cnt': 17,
#   'description': '한훈 농림축산식품부(이하 농식품부) 차관이 17일 <b>수원시</b> 농산물도매시장을 찾아 김장철 주요 농산물... 이어 &quot;도매시장에서도 김장철 소비자 장바구니 <b>물가</b>부담 완화를 위해 산지의 농산물 수집 강화와 원활한 유통거래에... ',
#   'link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2058563',
#   'org_link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2058563',
#   'pDate': '2023-11-17 16:30:00',
#   'title': '농식품부, 농산물도매시장 수급현황 현장점검'},
#  {'cnt': 18,
#   'description': '16일 <b>수원시</b> 팔달구 미나리 못골시장의 한 가게에서 배추·무·대파 등 김장재료가 진열 돼 있다. 사진=박성천 기자 올해 김장<b>물가</b>는 마트보다 시장에서 6만5천 원 저렴한 것으로 조사됐다. 16일 전문가격 조사기관... ',
#   'link': 'http://www.joongboo.com/news/articleView.html?idxno=363621246',
#   'org_link': 'http://www.joongboo.com/news/articleView.html?idxno=363621246',
#   'pDate': '2023-11-16 16:42:00',
#   'title': "김장 재료 직접 사봤더니… 마트보다 시장이 '8천70원' 저렴"},
#  {'cnt': 19,
#   'description': '기준을 통과하면 재지정하고, 부적격업소로 판단될 경우 지정을 취소한 후 인증 표찰을 회수하게 된다. 이재준 <b>수원시</b>장은 “지역 <b>물가</b> 안정에 기여하는 착한가격 업소를 많이 발굴해 시민들에게 널리 알리겠다”고 말했다.',
#   'link': 'https://www.donga.com/news/Society/article/all/20231116/122200750/1',
#   'org_link': 'https://www.donga.com/news/Society/article/all/20231116/122200750/1',
#   'pDate': '2023-11-16 03:03:00',
#   'title': '<b>수원시</b> “새로운 ‘착한가격 업소’ 발굴”'},
#  {'cnt': 20,
#   'description': "경기 <b>수원시</b>가 <b>물가</b> 인상 억제 분위기를 확산하기 위해 12월 15일까지 '착한가격업소'를 일제 정비한다. 관련 홍보물 [사진=<b>수원시</b>] 15일 시에 따르면 착한가격업소는 지역 평균 <b>물가</b>보다 낮은 가격으로 서비스를 제공해... ",
#   'link': 'http://www.newspim.com/news/view/20231115001322',
#   'org_link': 'http://www.newspim.com/news/view/20231115001322',
#   'pDate': '2023-11-15 17:38:00',
#   'title': "<b>수원시</b>, 2023년 하반기 '착한가격업소' 일제 정비 나서"},
#  {'cnt': 21,
#   'description': '경기도 <b>수원시</b>는 <b>물가</b> 인상 억제 분위기를 확산하기 위해 오는 12월 15일까지 하반기 ‘착한가격업소’를 일제 정비한다고 15일 밝혔다. 착한가격업소는 지역 평균 <b>물가</b>보다 낮은 가격으로 서비스를 제공해 지역 <b>물가</b>... ',
#   'link': 'http://www.shinailbo.co.kr/news/articleView.html?idxno=1787033',
#   'org_link': 'http://www.shinailbo.co.kr/news/articleView.html?idxno=1787033',
#   'pDate': '2023-11-15 17:20:00',
#   'title': '수원, 내달 15일까지 착한가격업소 일제정비'},
#  {'cnt': 22,
#   'description': "◆하반기 '착한가격업소' 일제 정비 <b>수원시</b>가 <b>물가</b> 인상 억제 분위기를 확산하기 위해 12월 15일까지 '착한가격업소'를 일제 정비한다. 착한가격업소는 지역 평균 <b>물가</b>보다 낮은 가격으로 서비스를 제공해 지역 <b>물가</b>... ",
#   'link': 'http://www.newsworks.co.kr/news/articleView.html?idxno=733629',
#   'org_link': 'http://www.newsworks.co.kr/news/articleView.html?idxno=733629',
#   'pDate': '2023-11-15 14:34:00',
#   'title': '[<b>수원시</b>소식] 사회복지종사자 화합 운동회 개최·하반기 착한가격업소 일제 정...'},
#  {'cnt': 23,
#   'description': '<b>수원시</b>가 <b>물가</b> 인상 억제 분위기를 확산하기 위해 다음 달 15일까지 ‘착한가격업소’를 일제 정비한다. 착한가격업소는 지역 평균 <b>물가</b>보다 낮은 가격으로 서비스를 제공해 지역 <b>물가</b> 안정에 기여하는 업소다. 청결·위생... ',
#   'link': 'https://www.seoul.co.kr/news/newsView.php?id=20231115500097&wlog_tag3=naver',
#   'org_link': 'https://www.seoul.co.kr/news/newsView.php?id=20231115500097&wlog_tag3=naver',
#   'pDate': '2023-11-15 13:47:00',
#   'title': '<b>수원시</b>, 올해 하반기 착한가격업소 일제 정비 나서'},
#  {'cnt': 24,
#   'description': "착한가격업소 홍보물(사진=<b>수원시</b>) <b>수원시</b>가 <b>물가</b> 인상 억제 분위기를 확산하기 위해 오는 12월 15일까지 '착한가격업소'를 일제 정비한다. 착한가격업소는 지역 평균 <b>물가</b>보다 낮은 가격으로 서비스를 제공해 지역 <b>물가</b>... ",
#   'link': 'https://www.kmaeil.com/news/articleView.html?idxno=425367',
#   'org_link': 'https://www.kmaeil.com/news/articleView.html?idxno=425367',
#   'pDate': '2023-11-15 13:42:00',
#   'title': '<b>수원시</b>, 2023년 하반기 착한가격업소 일제 정비 실시'},
#  {'cnt': 25,
#   'description': "경기 <b>수원시</b>는 다음달 15일까지 '착한가격업소'를 일제 정비한다고 15일 밝혔다. 착한가격업소는 지역 평균 <b>물가</b>보다 낮은 가격으로 서비스를 제공해 지역 <b>물가</b> 안정에 기여하는 업소로 청결·위생·품질·서비스 등을... ",
#   'link': 'https://www.jeonmae.co.kr/news/articleView.html?idxno=993983',
#   'org_link': 'https://www.jeonmae.co.kr/news/articleView.html?idxno=993983',
#   'pDate': '2023-11-15 13:12:00',
#   'title': '<b>수원시</b>, 착한가격업소 일제 정비 나선다'},
#  {'cnt': 26,
#   'description': '하반기 착한가격업소 일제 정비 <b>수원시</b>가 <b>물가</b> 인상 억제 분위기를 확산하기 위해 12월 15일까지 ‘착한가격업소’를 일제 정비한다. 착한가격업소는 지역 평균 <b>물가</b>보다 낮은 가격으로 서비스를 제공해 지역 <b>물가</b> 안정에... ',
#   'link': 'https://www.asiatime.co.kr/article/20231115500063',
#   'org_link': 'https://www.asiatime.co.kr/article/20231115500063',
#   'pDate': '2023-11-15 10:28:00',
#   'title': "[15일 <b>수원시</b>] 기업유치위원회 '기업유치 홍보 전략' 논의 등"},
#  {'cnt': 27,
#   'description': "11월 27일까지 신규 착한가격업소 모집 <b>수원시</b>가 <b>물가</b> 인상 억제 분위기를 확산하기 위해 다음달 15일까지 '착한가격업소'를 일제 정비한다고 15일 밝혔다.착한가격업소는 지역 평균 <b>물가</b>보다 낮은 가격으로 서비스

#   'org_link': 'http://www.newsis.com/view/?id=NISX20231113_0002518814&cID=14001&pID=14000',
#   'pDate': '2023-11-13 14:20:00',
#   'title': '[수원소식]영통구 여성축구단, 경기도축구협회장기 우승 등'},
#  {'cnt': 34,
#   'description': '[유주환/경기 <b>수원시</b> 망포동 : 학자금대출 말고도 다른 생활비 대출이라든지, 이제 그것들이 계속 변동금리다... 임금 수준이 낮고 집세 부담이 큰 청년들이 높은 <b>물가</b>에 금리까지 치솟으면서 어려움이 더욱 가중되고... ',
#   'link': 'https://news.jtbc.co.kr/article/article.aspx?news_id=NB12151866',
#   'org_link': 'https://news.jtbc.co.kr/article/article.aspx?news_id=NB12151866',
#   'pDate': '2023-11-12 18:44:00',
#   'title': '&quot;못 갚아요&quot; 4년 새 7배…갈수록 팍팍해지는 청년들의 삶'},
#  {'cnt': 35,
#   'description': '이날은 마침 제28회 농업인의 날로, 농림축산식품부(장관 정황근)는 하루 전날인 10일 <b>수원시</b> 옛 농촌진흥청... 농사짓는 데는 돈이 많이 들지만, 농산물 가격은 제대로 보장되지 않아서다&quot;라며 &quot;<b>물가</b>가 올라 농산물... ',
#   'link': 'http://www.ikpnews.net/news/articleView.html?idxno=62047',
#   'org_link': 'http://www.ikpnews.net/news/articleView.html?idxno=62047',
#   'pDate': '2023-11-11 22:30:00',
#   'title': "'윤석열정권 퇴진', 레드카드 날린 농민들"},
#  {'cnt': 36,
#   'description': '경기 <b>수원시</b>에서 사회복무요원으로 복무 중인 A씨는 매달 생활고에 허덕인다. A씨는 복무하기 전만 해도... 사회복무요원이 되면서 월급은 쪼그라들었고, 퇴근 후 생활해야 하는 도심의 <b>물가</b>는 A씨에게는 더욱... ',
#   'link': 'https://www.nocutnews.co.kr/news/6043755',
#   'org_link': 'https://www.nocutnews.co.kr/news/6043755',
#   'pDate': '2023-11-11 06:17:00',
#   'title': "&quot;매일 저녁 라면…&quot; 생활고 사회복무요원에 '풀빵 정신'을"},
#  {'cnt': 37,
#   'description': "소방관과 농업인에 대한 처우 개선 및 지원, 불법 사금융 대응, 수도권 광역교통 및 <b>물가</b> 대책을 챙기며... 윤 대통령은 10일 경기 <b>수원시</b> 서호 잔디광장에서 열린 '제28회 농업인의 날 기념식'에 참석해 &quot;작년 우리 정부... ",
#   'link': 'https://www.etoday.co.kr/news/view/2301317',
#   'org_link': 'https://www.etoday.co.kr/news/view/2301317',
#   'pDate': '2023-11-11 06:02:00',
#   'title': "'외교 강행군' 앞둔 尹…노봉법 거부권 등 정국 고심"},
#  {'cnt': 38,
#   'description': "윤 대통령은 이날 오후 경기도 <b>수원시</b> 서호 잔디광장에서 개최된 '제28회 농업인의 날 기념식'에 참석해... 부정평가한 이유는 경제·민생·<b>물가</b>(24%), 독단적·일방적(9%) 순으로 나타났다. 자세한 내용은... ",
#   'link': 'https://www.mk.co.kr/article/10871820',
#   'org_link': 'https://www.mk.co.kr/article/10871820',
#   'pDate': '2023-11-10 17:15:00',
#   'title': '&quot;농업직불금 5조로 확대&quot; 尹 농민들 만나 재약속'},
#  {'cnt': 39,
#   'description': '<b>수원시</b>의 한 대형마트에 소주 참이슬 프레시가 진열돼 있는 모습. 신연경 기자 주류도매업단체가 소주의... 9일 한국종합주류도매업중앙회는 지난 8일 이사회에서 결의대회를 열고 정부의 <b>물가</b> 안정 정책에 동참하는... ',
#   'link': 'http://www.joongboo.com/news/articleView.html?idxno=363619966',
#   'org_link': 'http://www.joongboo.com/news/articleView.html?idxno=363619966',
#   'pDate': '2023-11-09 15:30:00',
#   'title': "소주 출고가 상승… 주류도매업단체, 당분간 가격 '동결'"},
#  {'cnt': 40,
#   'description': '한훈 농림축산식품부 차관이 지난 6일 <b>수원시</b> 농협유통 수원점을 방문, 김장철 농축산물 수급 상황을 점검하고 있다. 연합뉴스 제공 농림축산식품부는 한훈 차관을 <b>물가</b>안정책임관으로 지정하고 배추, 육류 등... ',
#   'link': 'https://www.kyeonggi.com/article/20231109580034',
#   'org_link': 'https://www.kyeonggi.com/article/20231109580034',
#   'pDate': '2023-11-09 11:04:00',
#   'title': '정부, <b>물가</b> 체감도 높은 28개 주요 농식품 중점 관리'},
#  {'cnt': 41,
#   'description': '사진은 7일 <b>수원시</b> 팔달구의 한 착한가격업소 모습. 2023.11.7 / &quot;<b>물가</b>는 종량제 봉투만 빼놓고 다 오른 것 같네요.&quot;<b>수원시</b> 팔달구 못골시장에서 손칼국수집을 운영하는 김모(66)씨는 &quot;최근 들어 가격이 오르지 않은 게 없다... ',
#   'link': 'http://www.kyeongin.com/main/view.php?key=20231107010001403',
#   'org_link': 'http://www.kyeongin.com/main/view.php?key=20231107010001403',
#   'pDate': '2023-11-07 20:12:00',
#   'title': "착한가격업소 '다시 착해지고파'… 치솟는 <b>물가</b>, 버틸수가 없다"},
#  {'cnt': 42,
#   'description': '7일 오후 <b>수원시</b>의 한 대형마트에서 한 시민이 햄 제품을 살펴보고 있다. 신연경 기자 고<b>물가</b> 현상이 이어지는 상황에서 소비자들이 실생활에서 느끼는 장바구니 <b>물가</b> 부담도 갈수록 커지고 있다. 7일... ',
#   'link': 'http://www.joongboo.com/news/articleView.html?idxno=363619506',
#   'org_link': 'http://www.joongboo.com/news/articleView.html?idxno=363619506',
#   'pDate': '2023-11-07 15:34:00',
#   'title': '집밥 차리기도 힘드네… 햄·된장·간장 등 가공식품 가격↑'},
#  {'cnt': 43,
#   'description': '정부가 식품 <b>물가</b> 안정을 위해 배추, 대파 등 김장 재료 및 사과 수급 점검에 나섰다. 6일 한훈 농림축산식품부 차관은 경기 <b>수원시</b> 농협 하나로마트를 방문해 김장철 농산물 수급 상황을 점검하고 소비자 의견을 들었다.... ',
#   'link': 'https://www.donga.com/news/Economy/article/all/20231106/122051348/1',
#   'org_link': 'https://www.donga.com/news/Economy/article/all/20231106/122051348/1',
#   'pDate': '2023-11-07 03:05:00',
#   'title': '‘못난이 사과’ 1500t 공급… 절반 가격까지 할인 판매'},
#  {'cnt': 44,
#   'description': '한훈 농림축산식품부 차관은 어제(6일) 경기 <b>수원시</b>에 있는 대형마트를 찾아 김장 <b>물가</b> 완화를 위한 정부 대책 반영 여부를 점검했습니다. 한 차관은 농축산물을 적정한 가격에 안정적으로 공급하려면, 농협의 농축산물... ',
#   'link': 'https://www.ytn.co.kr/_ln/0102_202311070211237955',
#   'org_link': 'https://www.ytn.co.kr/_ln/0102_202311070211237955',
#   'pDate': '2023-11-07 02:11:00',
#   'title': '농식품부, 김장재료 수급 상황 점검...&quot;<b>물가</b>안정 총력&quot;'},
#  {'cnt': 45,
#   'description': '한훈 농림축산식품부 차관은 오늘(6일) 경기 <b>수원시</b>에 있는 대형마트를 찾아 김장 <b>물가</b> 완화를 위한 정부 대책 반영 여부를 점검했습니다. 한 차관은 농축산물을 적정한 가격에 안정적으로 공급하려면, 농협의 농축산물... ',
#   'link': 'https://www.ytn.co.kr/_ln/0102_202311061641397398',
#   'org_link': 'https://www.ytn.co.kr/_ln/0102_202311061641397398',
#   'pDate': '2023-11-06 16:41:00',
#   'title': '농식품부, 김장재료 수급 상황 점검...&quot;<b>물가</b>안정 총력&quot;'},
#  {'cnt': 46,
#   'description': '한훈 농식품부 차관은 오늘 경기 <b>수원시</b> 하나로마트 수원점을 찾아 농축산물 수급 상황을 점검하고 &quot;정부는 김장철 <b>물가</b> 안정을 위해 주요 김장 재료 공급을 늘리고, 할인 지원 확대 등 최선의 노력을 다하겠다&quot;고... ',
#   'link': 'https://biz.sbs.co.kr/article_hub/20000142805?division=NAVER',
#   'org_link': 'https://biz.sbs.co.kr/article_hub/20000142805?division=NAVER',
#   'pDate': '2023-11-06 16:30:00',
#   'title': '농식품부 &quot;김장철 <b>물가</b> 안정에 총력…재료 공급 늘린다&quot;'},
#  {'cnt': 47,
#   'description': '농림축산식품부는 김장철을 앞두고 김장재료 공급을 늘리는 한편 할인지원 등을 통해 <b>물가</b>안정에 총력을 기울이겠다고 6일 밝혔다. 한훈 농식품부 차관은 이날 경기 <b>수원시</b> 하나로마트 수원점을 찾아 농축산물... ',
#   'link': 'https://www.sedaily.com/NewsView/29X4QN96GV',
#   'org_link': 'https://www.sedaily.com/NewsView/29X4QN96GV',
#   'pDate': '2023-11-06 16:21:00',
#   'title': '한훈 농식품부 차관 “김장<b>물가</b> 안정 위해 공급확대…할인 지원 노력”'},
#  {'cnt': 48,
#   'description': '본격적인 김장철을 앞두고 천일염 가격이 평년보다 60%이상 급등 하는 등 김장재료가격이 오르자 정부가 <b>물가</b>안정을 위해 총력전을 펼치기로 했다. 한훈 농식품부 차관은 6일 경기 <b>수원시</b> 하나로마트 수원점을... ',
#   'link': 'http://news.heraldcorp.com/view.php?ud=20231106000670',
#   'org_link': 'http://news.heraldcorp.com/view.php?ud=20231106000670',
#   'pDate': '2023-11-06 16:13:00',
#   'title': '천일염 60.8%↑…농식품부 &quot;공급 확대 등 김장철 <b>물가</b>안정에 총력&quot;'},
#  {'cnt': 49,
#   'description': '한훈 농식품부 차관은 이날 경기 <b>수원시</b> 하나로마트 수원점을 찾아 농축산물 수급 상황을 점검하고 &quot;정부는 김장철 <b>물가</b>안정을 위해 주요 김장재료 공급을 늘리고, 할인지원 확대 등 최선의 노력을 다하겠다&quot;고... ',
#   'link': 'https://www.yna.co.kr/view/AKR20231106045900030?input=1195m',
#   'org_link': 'https://www.yna.co.kr/view/AKR20231106045900030?input=1195m',
#   'pDate': '2023-11-06 16:00:00',
#   'title': '농식품부 &quot;김장철 <b>물가</b>안정에 총력…재료 공급 확대&quot;'},
#  {'cnt': 50,
#   'description': "경기 <b>수원시</b> 장다리로 음식문화거리를 찾아 외식<b>물가</b> 동향을 점검하고, 외식업 현장 상인들의 어려움을 직접 듣고 지원 방안을 모색했다. 강경성 산업통상자원부 2차관도 범부처 '석유시장점검단'의 발족 이후 첫... ",
#   'link': 'http://www.newsis.com/view/?id=NISX20231103_0002508885&cID=10401&pID=10400',
#   'org_link': 'http://www.newsis.com/view/?id=NISX20231103_0002508885&cID=10401&pID=10400',
#   'pDate': '2023-11-06 06:16:00',
#   'title': "정부, 업계에 <b>물가</b> 인상 자제 당부 나섰지만 효과는 '미지수'"},
#  {'cnt': 51,
#   'description': '<b>수원시</b>의 한 대형마트에서 시민이 우유를 고르고 있는 모습. 신연경 기자 최근 <b>물가</b> 오름세가 계속되자 정부가 태스크포스(TF)를 꾸려 우유와 커피 등 7개 주요 식품의 <b>물가</b>를 집중 관리에 나서기로 했다.... ',
#   'link': 'http://www.joongboo.com/news/articleView.html?idxno=363619049',
#   'org_link': 'http://www.joongboo.com/news/articleView.html?idxno=363619049',
#   'pDate': '2023-11-05 13:28:00',
#   'title': "'서민 먹거리' 우유·라면 가격 잡는다… 정부, <b>물가</b>관리 TF 가동"},
#  {'cnt': 52,
#   'description': '농식품부에 따르면 양주필 농식품부 식품산업정책관은 이날 경기 <b>수원시</b> 장다리로 음식문화거리를 찾아 외식<b>물가</b> 동향을 점검하고, 외식업 현장 상인들의 어려움을 직접 듣고 지원 방안을 모색했다. 외식<b>물가</b>는 지난해... ',
#   'link': 'http://www.econonews.co.kr/news/articleView.html?idxno=311129',
#   'org_link': 'http://www.econonews.co.kr/news/articleView.html?idxno=311129',
#   'pDate': '2023-11-03 21:42:00',
#   'title': '농식품부, 먹거리 <b>물가</b> 상승 억제…외식업계 인건비 등 경영부담 완화 지원 총...'},
#  {'cnt': 53,
#   'description': '농림축산식품부는 양주필 식품산업정책관이 3일 경기 <b>수원시</b> 장다리로 음식문화거리를 찾아 <b>물가</b>안정 정책에 협조를 요청했다고 밝혔습니다. 외식업주들은 농식품부에 최근 재료비, 인건비, 공공요금 등 모든 제반... ',
#   'link': 'https://news.kbs.co.kr/news/pc/view/view.do?ncd=7809472&ref=A',
#   'org_link': 'https://news.kbs.co.kr/news/pc/view/view.do?ncd=7809472&ref=A',
#   'pDate': '2023-11-03 17:58:00',
#   'title': '농식품부, 외식업계에 <b>물가</b>안정 협조요청…“부담 완화대책 추진”'},
#  {'cnt': 54,
#   'description': '양주필 농림축산식품부 식품산업정책관은 3일 <b>수원시</b> 장다리로 음식문화거리를 방문, 외식 <b>물가</b> 동향을 점검하고, 외식업 현장 상인들의 애로ㆍ건의 사항을 청취했다. 외식<b>물가</b>는 지난해 9월 정점을 기록한 이후... ',
#   'link': 'http://www.foodnews.co.kr/news/articleView.html?idxno=105257',
#   'org_link': 'http://www.foodnews.co.kr/news/articleView.html?idxno=105257',
#   'pDate': '2023-11-03 17:58:00',
#   'title': '외식업계, 인력난 해소 위한 정부 지원 요청'},
#  {'cnt': 55,
#   'description': '2023.11.3 /대통령실 제공 지난 2020년 10월 처음 <b>수원시</b> 영통구에서 한식집을 연 A씨는 정부가 최근 코로나19... A씨는 &quot;<b>물가</b> 및 대출 금리 상승 등으로 자영업자들이 어려움을 겪고 있는 만큼 지원금 환수 면제는 환영할만한... ',
',
#   'link': 'http://www.edaily.co.kr/news/newspath.asp?newsid=03749046635801784',
#   'org_link': 'http://www.edaily.co.kr/news/newspath.asp?newsid=03749046635801784',
#   'pDate': '2023-11-02 17:31:00',
#   'title': '일회용품 사용 규제 계도 기간 연장 수순...관건은 품목 범위'},
#  {'cnt': 62,
#   'description': '10월 경기도 소비자<b>물가</b>지수가 발표된 2일 오후 <b>수원시</b>의 한 대형마트에서 한 시민이 장을 보고 있다. 신연경 기자 지난달 경기도 소비자<b>물가</b>가 1년 전과 비교해 3.6% 오르며 3개월 연속 3%대를 기록했다. 중동지역... ',
#   'link': 'http://www.joongboo.com/news/articleView.html?idxno=363618787',
#   'org_link': 'http://www.joongboo.com/news/articleView.html?idxno=363618787',
#   'pDate': '2023-11-02 15:24:00',
#   'title': '불안이 부른 고<b>물가</b>… 10월 경기도 소비자<b>물가</b> 3.6% 상승'},
#  {'cnt': 63,
#   'description': '이날 <b>수원시</b>의 한 대형마트에서 만난 임모(60대)씨는 &quot;슬슬 김장 준비를 하려고 하는데, 모든 품목의 <b>물가</b>가 다 오르는 것 같아 부담스럽다&quot;며 &quot;보통 김장을 한 번 하면 여러 종류의 김치를 담그는 편인데, 종류든... ',
#   'link': 'http://www.kyeongin.com/main/view.php?key=20231101010000261',
#   'org_link': 'http://www.kyeongin.com/main/view.php?key=20231101010000261',
#   'pDate': '2023-11-01 20:06:00',
#   'title': '다가온 김장철, 무서운 金추값'},
#  {'cnt': 64,
#   'description': '31일 <b>수원시</b>의 한 편의점에 진열된 하이트진로 소주 제품들. 신연경 기자 하이트진로가 내달 9일부터 소주... 이어 &quot;정부의 <b>물가</b>안정 노력에 발맞추고 소비자들의 부담을 최소화하는 선에서 인상률을 결정했다&quot;고... ',
#   'link': 'http://www.joongboo.com/news/articleView.html?idxno=363618289',
#   'org_link': 'http://www.joongboo.com/news/articleView.html?idxno=363618289',
#   'pDate': '2023-10-31 16:06:00',
#   'title': '소주·맥주 한잔도 어렵네…9일부터 참이슬·테라·켈리 가격↑'},
#  {'cnt': 65,
#   'description': '경기도 <b>수원시</b> 수원역 맞은 편 로데오거리 입구 광장에서 열린 제9차  ‘윤석열 퇴진’ 진보·중도·보수연대... 경제성장률도 심각하다”며 “금리는 폭등하는데 가계부채는 폭증하고 <b>물가</b>는 계속 오르는데 실질 임금은... ',
#   'link': 'https://www.mediawatch.kr/news/article.html?no=256838',
#   'org_link': 'https://www.mediawatch.kr/news/article.html?no=256838',
#   'pDate': '2023-10-30 16:40:00',
#   'title': '주말 수원서 열린 제9차 ‘윤석열 퇴진’ 진보·중도·보수연대 범국민대회 성...'},
#  {'cnt': 66,
#   'description': '<b>수원시</b>에 사는 65세 주부 김 모씨는 &quot;김장할 때 사실 배추를 절이는 일이 김장의 절반을 차지한다고 보면... 김장 재료인 고춧가루, 굵은소금 등의 가격도 예년에 비해 크게 올라 소비자들의 김장 <b>물가</b> 부담이... ',
#   'link': 'https://www.asiatime.co.kr/article/20231030500281',
#   'org_link': 'https://www.asiatime.co.kr/article/20231030500281',
#   'pDate': '2023-10-30 15:52:00',
#   'title': "김장 재료 값 오르자 '절임배추' 불티…'김장 포기족'에 포장김치도 인기"},
#  {'cnt': 67,
#   'description': '경기 <b>수원시</b>(119만명)보다는 많고 광주광역시(143만명)보다는 적다. 에스토니아의 국토 면적은 4만5228㎢로... 그는 “<b>물가</b>가 크게 뛰고 국제 정세로 인해 에스토니아산 목재가 경쟁력을 더 갖추게 됐다”고 덧붙였다.... ',
#   'link': 'https://realty.chosun.com/site/data/html_dir/2023/10/27/2023102702146.html',
#   'org_link': 'https://realty.chosun.com/site/data/html_dir/2023/10/27/2023102702146.html',
#   'pDate': '2023-10-30 07:02:00',
#   'title': '&quot;주택 20채 하루 만에 뚝딱&quot; GDP 100위권 국가의 반전, 목조주택 수출 1위로 ...'},
#  {'cnt': 68,
#   'description': '25일 도에 따르면 <b>수원시</b> 팔달구 옛 도청사(6만5천900㎡) 10개 동 중 제1별관(2천436㎡), 가족다문화과동(164... 도는 지난해 기록원 건립 비용을 240여억 원으로 책정했으나 최근 원재룟값 상승과 <b>물가</b> 인상 따위 여파로 약... ',
#   'link': 'http://www.kihoilbo.co.kr/news/articleView.html?idxno=1055145',
#   'org_link': 'http://www.kihoilbo.co.kr/news/articleView.html?idxno=1055145',
#   'pDate': '2023-10-25 21:36:00',
#   'title': "도기록원 설립 행정 지연·예산 증가 '난항'"},
#  {'cnt': 69,
#   'description': '고<b>물가</b>에 신선식품 온라인 구매가 더 높아지고 있다. 티몬이 최근 2달간(9.1~10.23) 주요 신선식품 카테고리... (경기도 <b>수원시</b>)에서 ‘NS농수산 홈쇼핑아카데미’를 실시했다. 홈쇼핑 입점을 희망하는 중소기업을... ',
#   'link': 'http://www.g-enews.com/ko-kr/news/article/news_all/202310250903284228a96f092d0c_1/article.html',
#   'org_link': 'http://www.g-enews.com/ko-kr/news/article/news_all/202310250903284228a96f092d0c_1/article.html',
#   'pDate': '2023-10-25 16:02:00',
#   'title': '[유통산책] SPC 쉐이크쉑, 27호점 목동점 개점 外'},
#  {'cnt': 70,
#   'description': "모았다&quot;며 &quot;장바구니 <b>물가</b>가 지속 상승하는 가운데, 다양한 기획전을 통해 고객들이 필요한 상품을 더욱... NS홈쇼핑이 지난 24일부터 25일까지 농수산식품유통교육원(경기도 <b>수원시</b>)에서 'NS농수산 홈쇼핑아카데미'를... ",
#   'link': 'http://www.greened.kr/news/articleView.html?idxno=307770',
#   'org_link': 'http://www.greened.kr/news/articleView.html?idxno=307770',
#   'pDate': '2023-10-25 09:34:00',
#   'title': '[유통가 레이더] &quot;어르신들의 특별한 변신을 응원합니다&quot;... 배민, 인생화보 ...'},
#  {'cnt': 71,
#   'description': '23일 <b>수원시</b> 경기도청에서 열린 국회 교통위원회의 경기도에 대한 국정감사에서 김희국 국민의힘 의원이... 서울시와 민간사업자가 6년간 협상을 거쳐 기획재정부에 올렸는데 기재부는 <b>물가</b>상승 등을 이유로 사업을... ',
#   'link': 'http://www.kyeongin.com/main/view.php?key=20231023010004121',
#   'org_link': 'http://www.kyeongin.com/main/view.php?key=20231023010004121',
#   'pDate': '2023-10-23 14:52:00',
#   'title': '[경기도 국감] 김희국 &quot;위례신사선·지하철 5호선 등 광역교통대책 서둘러야&quot;'},
#  {'cnt': 72,
#   'description': '&quot; 1999년 가게 문을 열어 25년째 <b>수원시</b> 팔달구 인계동에서 식당을 운영중인 곽문수 무영쌈밥정식 대표는 이... 곽 대표는 &quot;최근 인건비, 가스비, 재료비 등 전체적인 <b>물가</b> 상승으로 운영 비용이 부담된다&quot;면서도 &quot;오랜 기간... ',
#   'link': 'http://www.joongboo.com/news/articleView.html?idxno=363616701',
#   'org_link': 'http://www.joongboo.com/news/articleView.html?idxno=363616701',
#   'pDate': '2023-10-22 20:40:00',
#   'title': '[사람in] 곽문수 무영쌈밥정식 대표 &quot;한결 같은 마음으로 식당·지역사회 발전...'},
#  {'cnt': 73,
#   'description': "[A 씨 / 경기 <b>수원시</b> 공인중개사 : 저는 그 사람 거 단 한 개도 안 했어요. 등기부 등본을 떼어봤을 때... &quot;경제가 얼어붙는 것도 감수하겠다.&quot; '금리 인상'이라는 전제가 생략된 발언일 거고요, <b>물가</b>를 안정시키는 게... ",
#   'link': 'https://www.ytn.co.kr/_ln/0103_202310200839024417',
#   'org_link': 'https://www.ytn.co.kr/_ln/0103_202310200839024417',
#   'pDate': '2023-10-20 08:39:00',
#   'title': '흉기와 염산 들고 도주한 수배자...영화 같은 검거 작전 [띵동 이슈배달]'},
#  {'cnt': 74,
#   'description': '경기도 <b>수원시</b>는 오는 24일까지 착한가격업소로 지정된 51개 사업장을 대상으로 소독·방역서비스를 지원한다고 19일 밝혔다. ‘착한가격업소’는 지역 평균 <b>물가</b>보다 낮은 가격으로 서비스를 제공해 지역 <b>물가</b> 안정에... ',
#   'link': 'http://www.shinailbo.co.kr/news/articleView.html?idxno=1774327',
#   'org_link': 'http://www.shinailbo.co.kr/news/articleView.html?idxno=1774327',
#   'pDate': '2023-10-19 17:00:00',
#   'title': '수원, 착한가격업소 소독·방역서비스 지원'},
#  {'cnt': 75,
#   'description': '(사진=<b>수원시</b>청 제공) [수원=임종인 기자] 경기 <b>수원시</b>는 오는 24일까지 착한가격업소로 지정된 51개 사업장을 대상으로 소독·방역서비스를 지원한다고 19일 밝혔다. 시에 따르면 ‘착한가격업소’는 지역 평균 <b>물가</b>보다... ',
#   'link': 'https://www.siminilbo.co.kr/news/newsview.php?ncode=1160284753385443',
#   'org_link': 'https://www.siminilbo.co.kr/news/newsview.php?ncode=1160284753385443',
#   'pDate': '2023-10-19 16:12:00',
#   'title': '<b>수원시</b>, 착한가격업소에 소독·방역서비스'},
#  {'cnt': 76,
#   'description': '©열린뉴스통신ONA  <b>수원시</b>(시장 이재준)가 오는 24일까지 착한가격업소로 지정된 51개 사업장을 대상으로 소독·방역서비스를 지원한다고 밝혔다. 착한가격업소는 지역 평균 <b>물가</b>보다 낮은 가격으로 서비스를 제공해 지역... ',
#   'link': 'https://www.onews.tv/news/articleView.html?idxno=184210',
#   'org_link': 'https://www.onews.tv/news/articleView.html?idxno=184210',
#   'pDate': '2023-10-19 15:12:00',
#   'title': '<b>수원시</b>, 착한가격업소 51곳 소독·방역서비스 지원 나서'},
#  {'cnt': 77,
#   'description': "◆착한가격업소 '소독' 지원 <b>수원시</b>가 오는 24일까지 착한가격업소로 지정된 51개 사업장을 대상으로 소독·방역서비스를 지원한다. '착한가격업소'는 지역 평균 <b>물가</b>보다 낮은 가격으로 서비스를 제공해 지역 <b>물가</b>... ",
#   'link': 'http://www.newsworks.co.kr/news/articleView.html?idxno=730665',
#   'org_link': 'http://www.newsworks.co.kr/news/articleView.html?idxno=730665',
#   'pDate': '2023-10-19 13:50:00',
#   'title': "[<b>수원시</b> 소식] 새빛 솔로라이프 스테이션 운영·착한가격업소 '소독' 지원·생..."},
#  {'cnt': 78,
#   'description': '경기 <b>수원시</b>는 오는 24일까지 착한가격업소로 지정된 51개 사업장을 대상으로 소독·방역서비스를... 시 관계자는 &quot;어려운 경제 여건 속에서도 저렴한 가격과 우수한 서비스로 지역<b>물가</b> 안정에 기여하고 있
#   'org_link': 'https://www.youthdaily.co.kr/news/article.html?no=137505',
#   'pDate': '2023-10-16 09:04:00',
#   'title': '서울시민 10명 중 8명 &quot;기후동행카드 이용 의향 있다&quot;'},
#  {'cnt': 90,
#   'description': '대중교통 요금 인상과 <b>물가</b> 상승으로 인한 가계 부담을 덜고 생활권을 공유하는 수도권 교통 편의를... 경기도와 인천·<b>수원시</b> 등 수도권 및 다른 지역으로 연계 적용이 필요하다는 것이다. 또 공항철도, 심야버스... ',
#   'link': 'http://www.wowtv.co.kr/NewsCenter/News/Read?articleId=A202310160017&t=NN',
#   'org_link': 'http://www.wowtv.co.kr/NewsCenter/News/Read?articleId=A202310160017&t=NN',
#   'pDate': '2023-10-16 06:28:00',
#   'title': '서울시민 10명 중 8명 &quot;기후동행카드 이용할 것&quot;'},
#  {'cnt': 91,
#   'description': '대중교통 요금 인상과 <b>물가</b> 상승으로 인한 가계 부담을 덜고 생활권을 공유하는 수도권 교통 편의를... 경기도와 인천·<b>수원시</b> 등 수도권 및 다른 지역으로 연계 적용이 필요하다는 것이다. 또 공항철도, 심야버스... ',
#   'link': 'https://www.yna.co.kr/view/AKR20231013163200004?input=1195m',
#   'org_link': 'https://www.yna.co.kr/view/AKR20231013163200004?input=1195m',
#   'pDate': '2023-10-16 06:07:00',
#   'title': '서울시민 10명 중 8명 &quot;기후동행카드 이용 의향…도입 만족&quot;'},
#  {'cnt': 92,
#   'description': '부진·<b>물가</b> 상승 대비한 수급 대책 뒤따라야&quot; 광주시 송정매일시장에 강원도산 배추가 진열돼 있는 모습. 뉴시스 경기 <b>수원시</b>에 사는 주부 유 모씨(35)는 김장철을 앞두고 고민이 이만저만이 아니다. 배춧값을 비롯해... ',
#   'link': 'http://www.segyebiz.com/newsView/20231011517675?OutUrl=naver',
#   'org_link': 'http://www.segyebiz.com/newsView/20231011517675?OutUrl=naver',
#   'pDate': '2023-10-11 15:32:00',
#   'title': "김장철 앞두고 배추·소금값 '들썩'…“차라리 사먹을래요”"},
#  {'cnt': 93,
#   'description': "◆착한가격업소 52개소 4분기 종량제 봉투 지원 <b>수원시</b>가 관내 착한가격업소 52개소에 4분기 쓰레기 종량제 봉투를 지원한다. '착한가격업소'는 지역 평균 <b>물가</b>보다 낮은 가격으로 서비스를 제공해 지역 <b>물가</b> 안정에... ",
#   'link': 'http://www.newsworks.co.kr/news/articleView.html?idxno=729787',
#   'org_link': 'http://www.newsworks.co.kr/news/articleView.html?idxno=729787',
#   'pDate': '2023-10-11 11:28:00',
#   'title': "[<b>수원시</b> 소식] 가족돌봄청년 대상 일자리 제공 업무협약·'찾아가는 1인가구 ..."},
#  {'cnt': 94,
#   'description': '/경기도 제공 <b>수원시</b>에서 홍보·인쇄업체를 운영 중인 경기도 청년 유영준(30)씨는 조만간 경기도가 출시할... 이날 현장에 참석한 경기도 청년 박성수(30)씨는 &quot;돈을 벌어도 높은 <b>물가</b> 탓에 미래를 위한 저축이 쉽지 않아... ',
#   'link': 'http://www.kyeongin.com/main/view.php?key=20231011010001567',
#   'org_link': 'http://www.kyeongin.com/main/view.php?key=20231011010001567',
#   'pDate': '2023-10-11 11:14:00',
#   'title': "저축·대출 1개 통장서 경기도 '기회사다리금융' 출시…6만명, 3천억 지원"},
#  {'cnt': 95,
#   'description': '10일 <b>수원시</b>에 따르면 ‘착한가격업소’는 지역 평균 <b>물가</b>보다 낮은 가격으로 서비스를 제공해 지역 <b>물가</b> 안정에 기여하는 업소로, 청결·위생, 품질, 서비스 등을... ',
#   'link': 'http://www.breaknews.com/991572',
#   'org_link': 'http://www.breaknews.com/991572',
#   'pDate': '2023-10-11 02:26:00',
#   'title': '<b>수원시</b>,종량제 봉투 지원'},
#  {'cnt': 96,
#   'description': '학생 입장이다보니 더 요금이 부담되는 것도 있습니다.&quot; 【 인터뷰 】 이세현 / 경기도 <b>수원시</b> 이의동... 생활<b>물가</b> 전반이 치솟는 상황에서 국민의 빠듯한 살림살이를 고려한 교통비 지원책이 절실하다는 목소리가... ',
#   'link': 'http://tbs.seoul.kr/news/newsView.do?typ_800=3&idx_800=3508050&seq_800=20500729',
#   'org_link': 'http://tbs.seoul.kr/news/newsView.do?typ_800=3&idx_800=3508050&seq_800=20500729',
#   'pDate': '2023-10-10 16:25:00',
#   'title': "신분당선에 GTX까지 왕복 1만원 '성큼'…대책은 정기할인권 뿐? [밀착취재T]"},
#  {'cnt': 97,
#   'description': '©열린뉴스통신ONA  <b>수원시</b>(시장 이재준)는 10일 지역 내 착한가격업소 52개소에 4분기 쓰레기 종량제 봉투를 지원한다고 밝혔다. 착한가격업소는 지역 평균 <b>물가</b>보다 낮은 가격으로 서비스를 제공해 지역 <b>물가</b> 안정에... ',
#   'link': 'https://www.onews.tv/news/articleView.html?idxno=183117',
#   'org_link': 'https://www.onews.tv/news/articleView.html?idxno=183117',
#   'pDate': '2023-10-10 15:22:00',
#   'title': '<b>수원시</b>, 4분기 착한가격업소 52곳 쓰레기 종량제 봉투 지원 나서'},
#  {'cnt': 98,
#   'description': '<b>수원시</b> 관계자는 &quot;저렴한 가격과 우수한 서비스로 지역<b>물가</b> 안정에 기여하고 있는 착한가격업소를 활성화해 지역<b>물가</b> 안정화를 도모할 것&quot;이라며 &quot;시민들과 관광객들에게 양질의 서비스를 제공할 수 있도록 하겠다&quot;고... ',
#   'link': 'https://www.asiatoday.co.kr/view.php?key=20231010010003834',
#   'org_link': 'https://www.asiatoday.co.kr/view.php?key=20231010010003834',
#   'pDate': '2023-10-10 14:18:00',
#   'title': '<b>수원시</b>, 착한가격업소 52곳에 4분기 종량제 봉투 지원'},
#  {'cnt': 99,
#   'description': '<b>수원시</b> 관계자는 “저렴한 가격과 우수한 서비스로 지역<b>물가</b> 안정에 기여하고 있는 착한가격업소를 활성화해 지역<b>물가</b> 안정화를 도모할 것”이라며, “시민들과 관광객들에게 양질의 서비스를 제공할 수 있도록... ',
#   'link': 'https://www.viva100.com/main/view.php?key=20231010010001828',
#   'org_link': 'https://www.viva100.com/main/view.php?key=20231010010001828',
#   'pDate': '2023-10-10 14:02:00',
#   'title': '<b>수원시</b>,착한가격업소52개소에4분기 종량제 봉투 지원'},
#  {'cnt': 100,
#   'description': '착한가격업소 현황은 행정안전부·<b>수원시</b> 홈페이지에서 확인할 수 있다. 시 관계자는 “저렴한 가격과 우수한 서비스로 지역<b>물가</b> 안정에 기여하고 있는 착한가격업소를 활성화해 지역<b>물가</b> 안정화를 도모하겠다”고... ',
#   'link': 'http://www.newsis.com/view/?id=NISX20231010_0002476920&cID=14001&pID=14000',
#   'org_link': 'http://www.newsis.com/view/?id=NISX20231010_0002476920&cID=14001&pID=14000',
#   'pDate': '2023-10-10 13:53:00',
#   'title': '<b>수원시</b>, 착한가격업소에 4분기 종량제 봉투 지원'},
#  {'cnt': 101,
#   'description': '<b>수원시</b> 관계자는 “저렴한 가격과 우수한 서비스로 지역<b>물가</b> 안정에 기여하고 있는 착한가격업소를 활성화해 지역<b>물가</b> 안정화를 도모할 것”이라며, “시민들과 관광객들에게 양질의 서비스를 제공할 수 있도록 하겠다”... ',
#   'link': 'http://news.heraldcorp.com/view.php?ud=20231010000554',
#   'org_link': 'http://news.heraldcorp.com/view.php?ud=20231010000554',
#   'pDate': '2023-10-10 13:50:00',
#   'title': '<b>수원시</b>,착한가격업소52개소 종량제 봉투 지원'},
#  {'cnt': 102,
#   'description': '경기지역 정치 1번지로 단일 기초단체 가운데 가장 많은 5석이 배정된 <b>수원시</b>는 지난 총선에서 민주당이... 의정부시의 주부 김모(48) 씨는 &quot;경기북부특별자치도 설치 등 정치 현안보다 <b>물가</b> 때문에 힘들다는 얘기가 엄마들... ',
#   'link': 'https://www.yna.co.kr/view/AKR20231006122800061?input=1195m',
#   'org_link': 'https://www.yna.co.kr/view/AKR20231006122800061?input=1195m',
#   'pDate': '2023-10-08 05:50:00',
#   'title': "[총선 6개월] '승부처' 수도권 민심 예측불허…&quot;민생 대안이 승부 관건&quot;"},
#  {'cnt': 103,
#   'description': '만60세 이상 <b>수원시</b> 거주민을 대상으로 하는 이 행사는 다양한 분야의 업체가 참여한다. 주최 측인 <b>수원시</b>... 사회적 가치를 창출하는 프로그램으로 전환하고 <b>물가</b>상승, 최저임금 수준 등을 반영한 적정 수준의 활동비를... ',
#   'link': 'http://www.suwonilbo.kr/news/articleView.html?idxno=302556',
#   'org_link': 'http://www.suwonilbo.kr/news/articleView.html?idxno=302556',
#   'pDate': '2023-10-05 17:56:00',
#   'title': '[사설] 양질의 노인 일자리 대책 시급하다'},
#  {'cnt': 104,
#   'description': '이런 와중에, 연휴가 끝나자마자 기다렸다는 듯 <b>물가</b>가 줄줄이 뛰고 있습니다. 사흘 전엔 우윳값이... [운형권/경기 <b>수원시</b> : 캔맥주는 평소에도 많이 먹죠. 2천원 선이면 거기서 또 한 5~6% 오르면 많이... ',
#   'link': 'https://news.jtbc.co.kr/article/article.aspx?news_id=NB12146655',
#   'org_link': 'https://news.jtbc.co.kr/article/article.aspx?news_id=NB12146655',
#   'pDate': '2023-10-04 20:06:00',
#   'title': "우유·맥주·지하철 요금까지 '도미노 인상'…커지는 서민 한숨"},
#  {'cnt': 105,
#   'description': '경기도 <b>수원시</b> 팔달구 못골시장이 명절 상차림 준비를 위해 장보러 온 시민들로 북적이고 있다. (사진=뉴시스) 6일간의 추석 연휴 기간 정치권을 바라보는 국민의 시선은 싸늘하게 얼어붙었습니다. 고<b>물가</b>·고환율·고금리... ',
#   'link': 'http://www.newstomato.com/ReadNews.aspx?no=1203120&inflow=N',
#   'org_link': 'http://www.newstomato.com/ReadNews.aspx?no=1203120&inflow=N',
#   'pDate': '2023-10-03 17:06:00',
#   'title': '&quot;경기 최악&quot;…한숨의 추석민심'},
#  {'cnt': 106,
#   'pDate': '2022-08-15 17:30:00',
#   'title': '[현장24시] &quot;재난지원금 200만원… 도배·장판도 못해요&quot;'},
#  {'cnt': 989,
#   'description': "'금상추' 입니다.&quot; 13일 경기 <b>수원시</b> 권선구의 한 전통시장에서 적상추, 깻잎 등 각종 채소류를 팔고 있는... 도내 소비자<b>물가</b>도 계속 오름세로 기록되며 지난달 6%대를 찍었다. 최근 기준으로 소비자<b>물가</b>가 6%대... ",
#   'link': 'https://www.news1.kr/articles/4772006',
#   'org_link': 'https://www.news1.kr/articles/4772006',
#   'pDate': '2022-08-13 10:00:00',
#   'title': "'금상추'라 불리는 상추…채솟값 폭등에 상인·서민들 '울상'"},
#  {'cnt': 990,
#   'description': "사진은 <b>수원시</b> 지동시장에서 장을 보는 시민들. 2022.7.6 / 경기도 민생 추경안을 심의 중인 경기도의회가 '농산물 할인쿠폰 지원사업'을 두고 질타를 쏟아냈다. 추석 명절을 앞두고 <b>물가</b>부담을 덜기 위해 마련된 사업인데... ",
#   'link': 'http://www.kyeongin.com/main/view.php?key=20220812010002389',
#   'org_link': 'http://www.kyeongin.com/main/view.php?key=20220812010002389',
#   'pDate': '2022-08-12 14:58:00',
#   'title': "전통시장 빠진 경기도 '농수산물 할인쿠폰' 경기도의회 질타"},
#  {'cnt': 991,
#   'description': "<b>수원시</b> 권선구 한 식당에서 주인이 10인 상을 준비하는 모습. /경인일보DB  저렴한 가격에 상품을 제공하는 '착한가격업소'들이 고공행진하는 <b>물가</b>로 인해 어려움을 겪고 있지만(8월 5일자 9면 보도='착한가격' 이름표 단... ",
#   'link': 'http://www.kyeongin.com/main/view.php?key=20220810010001956',
#   'org_link': 'http://www.kyeongin.com/main/view.php?key=20220810010001956',
#   'pDate': '2022-08-11 20:32:00',
#   'title': "정부 '착한가격업소' 만들고 구경만… 책임은 지자체 몫"},
#  {'cnt': 992,
#   'description': "■ 2022.08.11 오후 1:30 대한적십자사 경기지사, '집중호우 피해지역 긴급구호품 배부' 11일 경기 <b>수원시</b>... &quot;추석 <b>물가</b> 잡아야&quot; 윤석열 대통령은 11일 오전 서울 양재동 하나로마트에서 제5차 비상경제민생회의를 열고... ",
#   'link': 'https://www.joongang.co.kr/article/25093612',
#   'org_link': 'https://www.joongang.co.kr/article/25093612',
#   'pDate': '2022-08-11 10:34:00',
#   'title': '[포토타임] 군산 232㎜ 물폭탄… 도로 잠기고 옹벽 무너지고 피해 속출'},
#  {'cnt': 993,
#   'description': '백 위원장은 <b>물가</b>·민생 안정과 함께 민간 경제 활력을 높이는 것도 정무위의 목표로 삼았다. 이를 위해... 백 위원장은 ”신분당선 연장선 복선화 이후 구운역 신설 사업도 재임 동안 <b>수원시</b>와 함께 노력하겠다“면서 ”... ',
#   'link': 'https://www.kyeonggi.com/article/20220810580159',
#   'org_link': 'https://www.kyeonggi.com/article/20220810580159',
#   'pDate': '2022-08-10 17:08:00',
#   'title': '[국회상임위원장 인터뷰] 백혜련 정무위원장'},
#  {'cnt': 994,
#  {'cnt': 999,
#   'description': '이재준 <b>수원시</b>장은 &quot;코로나19, <b>물가</b> 상승 등으로 힘든 시기에 뜻깊은 나눔을 실천해주신 수원농협에 감사드린다&quot;며 &quot;효원미와 수원농협의 따뜻한 마음을 이웃들에게 잘 전달하겠다&quot;고 말했다. 이어 &quot;수원농협이 우리... ',
#   'link': 'http://www.paxetv.com/news/articleView.html?idxno=150986',
#   'org_link': 'http://www.paxetv.com/news/articleView.html?idxno=150986',
#   'pDate': '2022-08-08 18:48:00',
#   'title': '수원농협, 취약계층 <b>수원시</b>민에게 효원미 1000포 기부'},
#  {'cnt': 1000,
#   'description': '이재준 <b>수원시</b>장은 &quot;코로나19, <b>물가</b> 상승 등으로 힘든 시기에 뜻깊은 나눔을 실천해주신 수원농협에 감사드린다&quot;며 &quot;효원미와 수원농협의 따뜻한 마음을 이웃들에게 잘 전달하겠다&quot;고 말했다. 이어 &quot;수원농협이 우리... ',
#   'link': 'http://www.joongdo.co.kr/web/view.php?key=20220808010002255',
#   'org_link': 'http://www.joongdo.co.kr/web/view.php?key=20220808010002255',
#   'pDate': '2022-08-08 17:34:00',
#   'title': '<b>수원시</b>, 수원농협 취약계층 효원미 1000포 기부 받아'}]

# %% [markdown]
# ## 분석 데이터 추출

# %%
message = ''

for item in data:
    if 'description' in item.keys():
        message = message + re.sub(r'[^\w]', ' ', item['description']) +''

message #출력하여 내용 확인
# Out:
# '공원   b 물가  b  水 와 가까운  공세권    수세권 이라는 입지적 특성으로 시장에서 탄탄한 수요를 갖추고 있던    광교호수공원 인근에 위치한  b 수원시  b  영통구 원천동 광교중흥S클래스의 경우 전용 84B 가 지난 9월 15억3    경기도  b 수원시  b  권선구 수원메쎄에서 21일 열린  경기여성 JOB 페스타 2023 을 찾은 구직자들이 이력서를    이어   b 물가  b  급등에 따른 취업준비 비용 부담 증가 13 1   등의 순으로 답했다  대학생 30 3 는 올해 대졸    홍성걸 국민대 행정학과 교수는  공사 기간  b 물가  b  상승과 설계 변경 등으로 실제 비용은 예상보다 20 30  더     b 수원시  b 가 사업비를 20조원가량으로 추산한 대규모 사업인데 이 역시 예타 면제가 포함됐다  민주당은    5     b 수원시  b  1 5    수성구 1 3    성남시 1 3    용산구 고양시 1 2    종로구 1 1    강릉시 강서구 관악구    그 다음은  b 물가  b 안정 21 5    일자리 창출 8 3    사회양극화 해소 8 1    저출산 해결 7 9    복지확대 6 0    공원   b 물가  b  水 와 가까운  공세권    수세권 이라는 입지적 특성으로 시장에서 탄탄한 수요를 갖추고 있던    광교호수공원 인근에 위치한  b 수원시  b  영통구 원천동 광교중흥S클래스의 경우 전용 84B 가 지난 9월 15억3    한편  이날 퀴즈쇼에서는  b 물가  b  상승으로 식당의  이것  역시 가격이 올랐다고 문제가 출제됐다  정답은    이후 퀴즈에는  b 수원시  b 에 위치한  세계화장실협회 가 나오기도  해당 협회는 개발도상국에 화장실을 보급하고    경기  b 수원시  b  농산물도매시장을 찾아 배추  무 등 김장철 주요 농산물 반입 상황과 가격 동향
한가격업소는 지역 평균  b 물가  b 보다 낮은 가격으로 서비스를 제공해    경기도  b 수원시  b 는  b 물가  b  인상 억제 분위기를 확산하기 위해 오는 12월 15일까지 하반기  착한가격업소 를 일제 정비한다고 15일 밝혔다  착한가격업소는 지역 평균  b 물가  b 보다 낮은 가격으로 서비스를 제공해 지역  b 물가  b      하반기  착한가격업소  일제 정비  b 수원시  b 가  b 물가  b  인상 억제 분위기를 확산하기 위해 12월 15일까지  착한가격업소 를 일제 정비한다  착한가격업소는 지역 평균  b 물가  b 보다 낮은 가격으로 서비스를 제공해 지역  b 물가  b      b 수원시  b 가  b 물가  b  인상 억제 분위기를 확산하기 위해 다음 달 15일까지  착한가격업소 를 일제 정비한다  착한가격업소는 지역 평균  b 물가  b 보다 낮은 가격으로 서비스를 제공해 지역  b 물가  b  안정에 기여하는 업소다  청결 위생    착한가격업소 홍보물 사진  b 수원시  b    b 수원시  b 가  b 물가  b  인상 억제 분위기를 확산하기 위해 오는 12월 15일까지  착한가격업소 를 일제 정비한다  착한가격업소는 지역 평균  b 물가  b 보다 낮은 가격으로 서비스를 제공해 지역  b 물가  b     경기  b 수원시  b 는 다음달 15일까지  착한가격업소 를 일제 정비한다고 15일 밝혔다  착한가격업소는 지역 평균  b 물가  b 보다 낮은 가격으로 서비스를 제공해 지역  b 물가  b  안정에 기여하는 업소로 청결 위생 품질 서비스 등을    하반기 착한가격업소 일제 정비  b 수원시  b 가  b 물가  b  인상 억제 분위기를 확산하기 위해 12월 15일까지  착한가격업소 를 일제 정비한다  착한가격업소는 지역 평균  b 물가  b 보다 낮은 가격으로 서비스를 제공해 지역  b 물가  b  안정에    11월 27일까지 신규 착한가격업소 모집  b 수원시  b 가  b 물가  b  인상 억제 분위기를 확산하기 위해 다음달 15일까지  착한가격업소 를 일제 정비한다고 15일 밝혔다 착한가격업소는 지역 평균  b 물가  b 보다 낮은 가격으로 서비스를     b 수원시  b  관계자는  quot 코로나19로 인해 상권이 침체한 상황에서도 저렴한 가격과 우수한 서비스를 제공해 지역  b 물가  b  안정에 이바지하고 있는 착한가격업소를 점검하고  신규 발굴해 시민과 관광객들에게 질 높은 서비스를    저렴한 가격 양질 서비 ...

# %% [markdown]
# ## 품사 태깅 : 명사 추출

# %%
nlp = Okt()
message_N = nlp.nouns(message)
message_N   #출력하여 내용 확인
# Out:
# ['공원',
#  '물가',
#  '공세',
#  '권',
#  '입지',
#  '특성',
#  '시장',
#  '수요',
#  '광교',
#  '호수',
#  '공원',
#  '인근',
#  '위치',
#  '수원시',
#  '영통구',
#  '원천동',
#  '광교',
#  '중흥',
#  '클래스',
#  '경우',
#  '전용',
#  '지난',
#  '경기도',
#  '수원시',
#  '권선구',
#  '메',
#  '경기',
#  '여성',
#  '페스',
#  '타',
#  '구직',
#  '이력서',
#  '물가',
#  '급등',
#  '취업',
#  '준비',
#  '비용',
#  '부담',
#  '증가',
#  '등',
#  '순',
#  '답',
#  '대학생',
#  '올해',
#  '대졸',
#  '홍성걸',
#  '국민대',
#  '행정학',
#  '교수',
#  '공사',
#  '기간',
#  '물가',
#  '상승',
#  '설계',
#  '변경',
#  '등',
#  '실제',
#  '비용',
#  '예상',
#  '더',
#  '수원시',
#  '사업',
#  '비',
#  '추산',
#  '대규모',
#  '사업',
#  '이',
#  '역시',
#  '타',
#  '면제',
#  '포함',
#  '민주당',
#  '수원시',
#  '수성구',
#  '성남시',
#  '용산구',
#  '고양시',
#  '종로구',
#  '강릉시',
#  '강서구',
#  '관악구',
#  '그',
#  '다음',
#  '물가',
#  '안정',
#  '일자리',
#  '창',
#  '사회',
#  '양극화',
#  '해소',
#  '저출산',
#  '해결',
#  '복지',
#  '확대',
#  '공원',
#  '물가',
#  '공세',
#  '권',
#  '입지',
#  '특성',
#  '시장',
#  '수요',
#  '광교',
#  '호수',
#  '공원',
#  '인근',
#  '위치',
#  '수원시',
#  '영통구',
#  '원천동',
#  '광교',
#  '중흥',
#  '클래스',
#  '경우',
#  '전용',
#  '지난',
#  '한편',
#  '날',
#  '퀴즈쇼',
#  '물가',
#  '상승',
#  '식당',
#  '것',
#  '역시',
#  '가격',
#  '문제',
#  '출제',
#  '정답',
#  '이후',
#  '퀴즈',
#  '수원시',
#  '위치',
#  '세계',
#  '화장실',
#  '협회',
#  '해당',
#  '협회',
#  '개발도상국',
#  '화장실',
#  '보급',
#  '경기',
#  '수원시',
#  '농산물',
#  '도매시장',
#  '배추',
#  '무',
#  '등',
#  '김장',
#  '철',
#  '주요',
#  '농산물',
#  '반입',
#  '상황',
#  '가격',
#  '동향',
#  '점검',
#  '차관',
#  '농산물',
#  '도매시장',
#  '관계자',
#  '김장',
#  '철',
#  '소비자',
#  '장바구니',
#  '물가',
#  '부담',
#  '완화',
#  '위해',
#  '김용환',
#  '수원시',
#  '회장',
#  '올해',
#  '예산',
#  '부족',
#  '더',
#  '분',
#  '지원',
#  '내년',
#  '더',
#  '분',
#  '마음',
#  '수',
#  '노력',
#  '김장',
#  '철',
#  '물가',
#  '겨울',
#  '추위',
#  '조금',
#  '위안',
#  '농림축산식품부',
#  '한훈',
#  '차관',
#  '수원시',
#  '농산물',
#  '도매시장',
#  '방문',
#  '김장',
#  '철',
#  '주요',
#  '농산물',
#  '반입',
#  '물량',
#  '상황',
#  '도매시장',
#  '김장',
#  '철',
#  '소비자',
#  '장바구니',
#  '물가',
#  '부담',
#  '완화',
#  '위해',
#  '산지',
#  '농산물',
#  '수집',
#  '강화',
#  '한훈',
#  '농림축산식품부',
#  '차관',
#  '사진',
#  '농식품부',
#  '뉴스',
#  '통신',
#  '한훈',
#  '농림축산식품부',
#  '차관',
#  '오후',
#  '수원시',
#  '장바구니',
#  '물가',
#  '부담',
#  '완화',
#  '위해',
#  '산지',
#  '농산물',
#  '수집',
#  '강화',
#  '유통',
#  '거래',
#  '노력',
#  '줄',
#  '것',
#  '당부',
#  '김장',
#  '철',
#  '장바구니',
#  '물가',
#  '부담',
#  '완화',
#  '최선',
#  '한훈',
#  '농림축산식품부',
#  '차관',
#  '경기',
#  '수원시',
#  '농산물',
#  '도매시장',
#  '방문',
#  '김장',
#  '철',
#  '주요',
#  '농산물',
#  '반입',
#  '물량',
#  '상황',
#  '가격',
#  '동향',
#  '점검',
#  '도매시장',
#  '관계자',
#  '격려',
#  '현장',
#  '사진',
#  '서울',
#  '시내',
#  '마트',
#  '먹거리',
#  '물가',
#  '시민',
#  '가계',
#  '부담',
#  '가중',
#  '가운데',
#  '농식품부',
#  '해수부',
#  '연일',
#  '시장',
#  '점검',
#  '물가',
#  '안정',
#  '총력',
#  '농림축산식품부',
#  '수원시',
#  '한훈',
#  '농림축산식품부',
#  '차관',
#  '수원시',
#  '농산물',
#  '도매시장',
#  '방문',
#  '김장',
#  '철',
#  '주요',
#  '농산물',
#  '반입',
#  '물량',
#  '상황',
#  '가격',
#  '장바구니',
#  '물가',
#  '부담',
#  '완화',
#  '위해',
#  '산지',
#  '농산물',
#  '수집',
#  '유통',
#  '거래',
#  '노력',
#  '달라',
#  '고',
#  '배추',
#  '무',
#  '등',
#  '김장',
#  '주요',
#  '재료',
#  '유통',
#  '거래',
#  '위해',
#  '도매',
#  '단계',
#  '물가',
#  '안정',
#  '한훈',
#  '장바구니',
#  '물가',
#  '부담',
#  '완화',
#  '위해',
#  '산지',
#  '농산물',
#  '수집',
#  '강화',
#  '유통',
#  '거래',
#  '노력',
#  '고',
#  '당부',
#  '지난',
#  '경기',
#  '수원시',
#  '농산물',
#  '도매시장',
#  '배추',
#  '무',
#  '등',
#  '김장',
#  '철',
#  '주요',
#  '농산물',
#  '반입',
#  '상황',
#  '가격',
#  '동향',
#  '점검',
#  '차관',
#  '농산물',
#  '도매시장',
#  '관계자',
#  '김장',
#  '철',
#  '소비자',
#  '장바구니',
#  '물가',
#  '부담',
#  '완화',
#  '위해',
#  '한훈',
#  '농림축산식품부',
#  '차관',
#  '도매시장',
#  '김장',
#  '철',
#  '소비자',
#  '장바구니',
#  '물가',
#  '부담',
#  '완화',
#  '위해',
#  '산지',
#  '농산물',
#  '수집',
#  '강화',
#  '유통',
#  '거래',
#  '노력',
#  '달라',
#  '고',
#  '말',
#  '차관',
#  '날',
#  '경기',
#  '수원시',
#  '농산물',
#  '도매시장',
#  '한훈',
#  '농림축산식품부',
#  '이하',
#  '농식품부',
#  '차관',
#  '수원시',
#  '농산물',
#  '도매시장',
#  '김장',
#  '철',
#  '주요',
#  '농산물',
#  '도매시장',
#  '김장',
#  '철',
#  '소비자',
#  '장바구니',
#  '물가',
#  '부담',
#  '완화',
#  '위해',
#  '산지',
#  '농산물',
#  '수집',
#  '강화',
#  '유통',
#  '거래',
#  '수원시',
#  '팔달구',
#  '미나리',
#  '시장',
#  '가게',
#  '배추',
#  '무',
#  '대파',
#  '등',
#  '김장',
#  '재료',
#  '진열',
#  '사진',
#  '박성',
#  '기자',
#  '올해',
#  '김장',
#  '물가',
#  '마트',
#  '시장',
#  '원',
#  '것',
#  '조사',
#  '전문',
#  '가격',
#  '조사',
#  '기관',
#  '기준',
#  '통과',
#  '재',
#  '지정',
#  '부적',
#  '격업',
#  '소로',
#  '판단',
#  '경우',
#  '지정',
#  '취소',
#  '후',
#  '인증',
#  '표찰',
#  '회수',
#  '이재준',
#  '수원시',
#  '장',
#  '지역',
#  '물가',
#  '안정',
#  '기여',
#  '가격',
#  '업소',
#  '발굴',
#  '시민',
#  '널리',
#  '고',
#  '말',
#  '경기',
#  '수원시',
#  '물가',
#  '인상',
#  '억제',
#  '분위기',
#  '확산',
#  '위해',
#  '가격',
#  '를',
#  '일제',
#  '정비',
#  '관련',
#  '홍보물',
#  '사진',
#  '수원시',
#  '시',
#  '가격',
#  '업소',
#  '지역',
#  '평균',
#  '물가',
#  '가격',
#  '서비스',
#  '제공',
#  '경기도',
#  '수원시',
#  '물가',
#  '인상',
#  '억제',
#  '분위기',
#  '확산',
#  '위해',
#  '하반기',
#  '가격',
#  '를',
#  '일제',
#  '정비',
#  '가격',
#  '업소',
#  '지역',
#  '평균',
#  '물가',
#  '가격',
#  '서비스',
#  '제공',
#  '지역',
#  '물가',
#  '하반기',
#  '가격',
#  '일제',
#  '정비',
#  '수원시',
#  '물가',
#  '인상',
#  '억제',
#  '분위기',
#  '확산',
#  '위해',
#  '가격',
#  '를',
#  '일제',
#  '정비',
#  '가격',
#  '업소',
#  '지역',
#  '평균',
#  '물가',
#  '가격',
#  '서비스',
#  '제공',
#  '지역',
#  '물가',
#  '수원시',
#  '물가',
#  '인상',
#  '억제',
#  '분위기',
#  '확산',
#  '위해',
#  '다음',
#  '달',
#  '가격',
#  '를',
#  '일제',
#  '정비',
#  '가격',
#  '업소',
#  '지역',
#  '평균',
#  '물가',
#  '가격',
#  '서비스',
#  '제공',
#  '지역',
#  '물가',
#  '안정',
#  '기여',
#  '업소',
#  '청결',
#  '위생',
#  '가격',
#  '홍보물',
#  '사진',
#  '수원시',
#  '수원시',
#  '물가',
#  '인상',
#  '억제',
#  '분위기',
#  '확산',
#  '위해',
#  '가격',
#  '를',
#  '일제',
#  '정비',
#  '가격',
#  '업소',
#  '지역',
#  '평균',
#  '물가',
#  '가격',
#  '서비스',
#  '제공',
#  '지역',
#  '물가',
#  '경기',
#  '수원시',
#  '다음',
#  '달',
#  '가격',
#  '를',
#  '일제',
#  '정비',
#  '가격',
#  '업소',
#  '지역',
#  '평균',
#  '물가',
#  '가격',
#  '서비스',
#  '제공',
#  '지역',
#  '물가',
#  '안정',
#  '기여',
#  '업',
#  '소로',
#  '청결',
#  '위생',
#  '품질',
#  '서비스',
#  '등',
#  '하반기',
#  '가격',
#  '일제',
#  '정비',
#  '수원시',
#  '물가',
#  '인상',
#  '억제',
#  '분위기',
#  '확산',
#  '위해',
#  '가격',
#  '를',
#  '일제',
#  '정비',
#  '가격',
#  '업소',
#  '지역',
#  '평균',
#  '물가',
#  '가격',
#  '서비스',
#  '제공',
#  '지역',
#  '물가',
#  '안정',
#  '신규',
#  '가격',
#  '모집',
#  '수원시',
#  '물가',
#  '인상',
#  '억제',
#  '분위기',
#  '확산',
#  '위해',
#  '다음',
#  '달',
#  '가격',
#  '를',
#  '일제',
#  '정비',
#  '가격',
#  '업소',
#  '지역',
#  '평균',
#  '물가',
#  '가격',
#  '서비스',
#  '수원시',
#  '관계자',
#  '코로나',
#  '로',
#  '상권',
#  '침체',
#  '상황',
#  '가격',
#  '서비스',
#  '제공',
#  '지역',
#  '물가',
#  '안정',
#  '이바지',
#  '가격',
#  '업소',
#  '점검',
#  '신규',
#  '발굴',
#  '시민',
#  '관광객',
#  '질',
#  '서비스',
#  '가격',
#  '양질',
#  '서비스',
#  '고수',
#  '지자체',
#  '인',
#  '센티',
#  '브',
#  '당근',
#  '책',
#  '한몫',
#  '수원시',
#  '장안구',
#  '소재',
#  '사우나',
#  '입구',
#  '고',
#  '물가',
#  '부담',
#  '요금',
#  '인상',
#  '요금',
#  '지난달',
#  '경기도',
#  '평균',
#  '목욕',
#  '비',
#  '오후',
#  '수원시',
#  '의',
#  '대형',
#  '마트',
#  '시민',
#  '세탁',
#  '세제',
#  '등',
#  '생활용품',
#  '가격',
#  '연경',
#  '기자',
#  '고',
#  '물가',
#  '상황',
#  '계속',
#  '상황',
#  '최근',
#  '사이',
#  '먹거리',
#  '외',
#  '생활용품',
#  '가격',
#  '크게',
#  '오른',
#  '것',
#  '지난',
#  '제',
#  '농업인',
#  '날',
#  '행사',
#  '경기',
#  '수원시',
#  '서호',
#  '잔디',
#  '광장',
#  '윤석열',
#  '대통령',
#  '참석',
#  '가운데',
#  '역대',
#  '또',
#  '물가',
#  '안정',
#  '명목',
#  '물밀',
#  '듯이',
#  '수입',
#  '농축',
#  '수산물',
#  '농가',
#  '경제',
#  '이',
#  '여건',
#  '속',
#  '경기도',
#  '지난해',
#  '수원시',
#  '이의동',
#  '광교',
#  '청사',
#  '이전',
#  '도',
#  '청사',
#  '관리',
#  '비',
#  '반영',
#  '예산',
#  '유지비',
#  '원',
#  '운영',
#  '비',
#  '원',
#  '등',
#  '모두',
#  '원',
#  '달',
#  '물가',
#  '상승',
#  '등',
#  '반영',
#  '수원시',
#  '영통구',
#  '축구단',
#  '경기도',
#  '축구협회장',
#  '기',
#  '동호',
#  '축구',
#  '대회',
#  '여성부',
#  '우승',
#  '차지',
#  '현재',
#  '위탁',
#  '업체',
#  '계약',
#  '통해',
#  '운영',
#  '중인',
#  '구청',
#  '구내식당',
#  '식',
#  '자재',
#  '물가',
#  '상승',
#  '기존',
#  '식비',
#  '식사',
#  '유주',
#  '환',
#  '경기',
#  '수원시',
#  '망포동',
#  '학자금대출',
#  '다른',
#  '생활비',
#  '대출',
#  '이제',
#  '그것',
#  '계속',
#  '변동',
#  '금리',
#  '임금',
#  '수준',
#  '집세',
#  '부담',
#  '청년',
#  '물가',
#  '금리',
#  '어려움',
#  '더욱',
#  '가중',
#  '날',
#  '마침',
#  '제',
#  '농업인',
#  '날로',
#  '농림축산식품부',
#  '장관',
#  '정황',
#  '하루',
#  '전날',
#  '수원시',
#  '농촌진흥청',
#  '데',
#  '돈',
#  '농산물',
#  '가격',
#  '제대로',
#  '보장',
#  '라며',
#  '물가',
#  '농산물',
#  '경기',
#  '수원시',
#  '사회',
#  '복무',
#  '요원',
#  '복무',
#  '중인',
#  '씨',
#  '매달',
#  '생활고',
#  '씨',
#  '복무',
#  '전만',
#  '해도',
#  '사회',
#  '복무',
#  '요원',
#  '월급',
#  '퇴근',
#  '후',
#  '생활',
#  '도심',
#  '물가',
#  '씨',
#  '더욱',
#  '소방관',
#  '농업인',
#  '대한',
#  '처우',
#  '개선',
#  '및',
#  '지원',
#  '불법',
#  '사금융',
#  '대응',
#  '수도권',
#  '광역',
#  '교통',
#  '및',
#  '물가',
#  '대책',
#  '윤',
#  '대통령',
#  '경기',
#  '수원시',
#  '서호',
#  '잔디',
#  '광장',
#  '제',
#  '농업인',
#  '날',
#  '기념',
#  '참석',
#  '작년',
#  '우리',
#  '정부',
#  '윤',
#  '대통령',
#  '날',
#  '오후',
#  '경기도',
#  '수원시',
#  '서호',
#  '잔디',
#  '광장',
#  '개최',
#  '제',
#  '농업인',
#  '날',
#  '기념',
#  '참석',
#  '부정',
#  '평가',
#  '이유',
#  '경제',
#  '민생',
#  '물가',
#  '독단',
#  '일방',
#  '순',
#  '내용',
#  '수원시',
#  '의',
#  '대형',
#  '마트',
#  '소주',
#  '참이슬',
#  '프레',
#  '시가',
#  '진열',
#  '모습',
#  '연경',
#  '기자',
#  '주류',
#  '도매',
#  '업',
#  '단체',
#  '소주',
#  '한국',
#  '종합',
#  '주류',
#  '도매',
#  '업',
#  ...]

# %% [markdown]
# ## 단어 빈도 탐색

# %%
count = Counter(message_N)

count   #출력하여 내용 확인
# Out:
# Counter({'공원': 6,
#          '물가': 1142,
#          '공세': 2,
#          '권': 10,
#          '입지': 2,
#          '특성': 2,
#          '시장': 226,
#          '수요': 19,
#          '광교': 17,
#          '호수': 2,
#          '인근': 10,
#          '위치': 36,
#          '수원시': 1131,
#          '영통구': 42,
#          '원천동': 6,
#          '중흥': 4,
#          '클래스': 4,
#          '경우': 25,
#          '전용': 15,
#          '지난': 109,
#          '경기도': 246,
#          '권선구': 51,
#          '메': 2,
#          '경기': 289,
#          '여성': 11,
#          '페스': 45,
#          '타': 45,
#          '구직': 1,
#          '이력서': 1,
#          '급등': 9,
#          '취업': 8,
#          '준비': 23,
#          '비용': 13,
#          '부담': 71,
#          '증가': 12,
#          '등': 371,
#          '순': 7,
#          '답': 4,
#          '대학생': 4,
#          '올해': 56,
#          '대졸': 1,
#          '홍성걸': 1,
#          '국민대': 1,
#          '행정학': 1,
#          '교수': 4,
#          '공사': 7,
#          '기간': 21,
#          '상승': 327,
#          '설계': 4,
#          '변경': 3,
#          '실제': 14,
#          '예상': 8,
#          '더': 45,
#          '사업': 50,
#          '비': 65,
#          '추산': 1,
#          '대규모': 25,
#          '이': 112,
#          '역시': 9,
#          '면제': 2,
#          '포함': 7,
#          '민주당': 6,
#          '수성구': 1,
#          '성남시': 46,
#          '용산구': 1,
#          '고양시': 4,
#          '종로구': 2,
#          '강릉시': 2,
#          '강서구': 1,
#          '관악구': 1,
#          '그': 25,
#          '다음': 13,
#          '안정': 181,
#          '일자리': 37,
#          '창': 3,
#          '사회': 16,
#          '양극화': 2,
#          '해소': 4,
#          '저출산': 1,
#          '해결': 3,
#          '복지': 24,
#          '확대': 25,
#          '한편': 14,
#          '날': 81,
#          '퀴즈쇼': 1,
#          '식당': 15,
#          '것': 138,
#          '가격': 330,
#          '문제': 17,
#          '출제': 1,
#          '정답': 1,
#          '이후': 29,
#          '퀴즈': 1,
#          '세계': 8,
#          '화장실': 3,
#          '협회': 6,
#          '해당': 4,
#          '개발도상국': 1,
#          '보급': 1,
#          '농산물': 39,
#          '도매시장': 21,
#          '배추': 17,
#          '무': 10,
#          '김장': 41,
#          '철': 27,
#          '주요': 16,
#          '반입': 5,
#          '상황': 132,
#          '동향': 66,
#          '점검': 25,
#          '차관': 22,
#          '관계자': 72,
#          '소비자': 158,
#          '장바구니': 29,
#          '완화': 17,
#          '위해': 144,
#          '김용환': 2,
#          '회장': 26,
#          '예산': 14,
#          '부족': 2,
#          '분': 10,
#          '지원': 80,
#          '내년': 58,
#          '마음': 10,
#          '수': 96,
#          '노력': 14,
#          '겨울': 21,
#          '추위': 3,
#          '조금': 20,
#          '위안': 1,
#          '농림축산식품부': 20,
#          '한훈': 17,
#          '방문': 70,
#          '물량': 9,
#          '산지': 6,
#          '수집': 7,
#          '강화': 8,
#          '사진': 54,
#          '농식품부': 14,
#          '뉴스': 17,
#          '통신': 12,
#          '오후': 64,
#          '유통': 17,
#          '거래': 30,
#          '줄': 5,
#          '당부': 2,
#          '최선': 5,
#          '격려': 5,
#          '현장': 24,
#          '서울': 19,
#          '시내': 2,
#          '마트': 54,
#          '먹거리': 11,
#          '시민': 83,
#          '가계': 7,
#          '가중': 6,
#          '가운데': 40,
#          '해수부': 1,
#          '연일': 3,
#          '총력': 3,
#          '달라': 6,
#          '고': 163,
#          '재료': 30,
#          '도매': 5,
#          '단계': 2,
#          '말': 58,
#          '이하': 6,
#          '팔달구': 62,
#          '미나리': 2,
#          '가게': 11,
#          '대파': 4,
#          '진열': 7,
#          '박성': 2,
#          '기자': 64,
#          '원': 59,
#          '조사': 15,
#          '전문': 4,
#          '기관': 14,
#          '기준': 19,
#          '통과': 1,
#          '재': 7,
#          '지정': 34,
#          '부적': 1,
#          '격업': 1,
#          '소로': 12,
#          '판단': 3,
#          '취소': 3,
#          '후': 16,
#          '인증': 3,
#          '표찰': 2,
#          '회수': 4,
#          '이재준': 85,
#          '장': 50,
#          '지역': 214,
#          '기여': 24,
#          '업소': 38,
#          '발굴': 5,
#          '널리': 1,
#          '인상': 178,
#          '억제': 22,
#          '분위기': 25,
#          '확산': 23,
#          '를': 128,
#          '일제': 25,
#          '정비': 29,
#          '관련': 27,
#          '홍보물': 2,
#          '시': 113,
#          '평균': 88,
#          '서비스': 79,
#          '제공': 64,
#          '하반기': 5,
#          '달': 45,
#          '청결': 4,
#          '위생': 4,
#          '업': 26,
#          '품질': 5,
#          '신규': 21,
#          '모집': 2,
#          '코로나': 38,
#          '로': 54,
#          '상권': 10,
#          '침체': 116,
#          '이바지': 2,
#          '관광객': 13,
#          '질': 39,
#          '양질': 13,
#          '고수': 2,
#          '지자체': 15,
#          '인': 23,
#          '센티': 15,
#          '브': 14,
#          '당근': 1,
#          '책': 7,
#          '한몫': 2,
#          '장안구': 37,
#          '소재': 34,
#          '사우나': 1,
#          '입구': 4,
#          '요금': 35,
#          '지난달': 36,
#          '목욕': 2,
#          '의': 100,
#          '대형': 49,
#          '세탁': 2,
#          '세제': 2,
#          '생활용품': 2,
#          '연경': 20,
#          '계속': 22,
#          '최근': 83,
#          '사이': 5,
#          '외': 4,
#          '크게': 32,
#          '오른': 13,
#          '제': 45,
#          '농업인': 6,
#          '행사': 69,
#          '서호': 3,
#          '잔디': 3,
#          '광장': 8,
#          '윤석열': 12,
#          '대통령': 17,
#          '참석': 8,
#          '역대': 7,
#          '또': 29,
#          '명목': 2,
#          '물밀': 1,
#          '듯이': 1,
#          '수입': 19,
#          '농축': 5,
#          '수산물': 18,
#          '농가': 2,
#          '경제': 185,
#          '여건': 62,
#          '속': 18,
#          '지난해': 50,
#          '이의동': 11,
#          '청사': 13,
#          '이전': 6,
#          '도': 46,
#          '관리': 68,
#          '반영': 70,
#          '유지비': 1,
#          '운영': 59,
#          '모두': 15,
#          '축구단': 1,
#          '축구협회장': 1,
#          '기': 35,
#          '동호': 1,
#          '축구': 2,
#          '대회': 5,
#          '여성부': 1,
#          '우승': 1,
#          '차지': 7,
#          '현재': 17,
#          '위탁': 3,
#          '업체': 8,
#          '계약': 15,
#          '통해': 26,
#          '중인': 10,
#          '구청': 4,
#          '구내식당': 1,
#          '식': 13,
#          '자재': 6,
#          '기존': 7,
#          '식비': 2,
#          '식사': 5,
#          '유주': 1,
#          '환': 2,
#          '망포동': 3,
#          '학자금대출': 1,
#          '다른': 11,
#          '생활비': 4,
#          '대출': 11,
#          '이제': 2,
#          '그것': 2,
#          '변동': 12,
#          '금리': 87,
#          '임금': 60,
#          '수준': 16,
#          '집세': 1,
#          '청년': 13,
#          '어려움': 93,
#          '더욱': 8,
#          '마침': 1,
#          '날로': 2,
#          '장관': 2,
#          '정황': 2,
#          '하루': 9,
#          '전날': 7,
#          '농촌진흥청': 1,
#          '데': 12,
#          '돈': 5,
#          '제대로': 2,
#          '보장': 7,
#          '라며': 31,
#          '복무': 4,
#          '요원': 7,
#          '씨': 71,
#          '매달': 2,
#          '생활고': 9,
#          '전만': 1,
#          '해도': 3,
#          '월급': 7,
#          '퇴근': 1,
#          '생활': 90,
#          '도심': 1,
#          '소방관': 1,
#          '대한': 26,
#          '처우': 1,
#          '개선': 6,
#          '및': 58,
#          '불법': 2,
#          '사금융': 1,
#          '대응': 43,
#          '수도권': 14,
#          '광역': 1,
#          '교통': 9,
#          '대책': 89,
#          '윤': 11,
#          '기념': 6,
#          '작년': 13,
#          '우리': 19,
#          '정부': 63,
#          '개최': 8,
#          '부정': 14,
#          '평가': 3,
#          '이유': 9,
#          '민생': 67,
#          '독단': 1,
#          '일방': 1,
#          '내용': 9,
#          '소주': 9,
#          '참이슬': 1,
#          '프레': 1,
#          '시가': 6,
#          '모습': 24,
#          '주류': 2,
#          '단체': 11,
#          '한국': 20,
#          '종합': 37,
#          '중앙회': 4,
#          '이사회': 1,
#          '결의': 4,
#          '정책': 25,
#          '동참': 23,
#          '농협유통': 1,
#          '원점': 8,
#          '농': 25,
#          '축산물': 9,
#          '수급': 10,
#          '연합뉴스': 6,
#          '책임': 4,
#          '관': 18,
#          '육류': 2,
#          '종량제': 9,
#          '봉투': 9,
#          '손': 1,
#          '칼국수': 1,
#          '집': 11,
#          '김모': 7,
#          '게': 13,
#          '햄': 1,
#          '제품': 9,
#          '현상': 8,
#          '실생활': 1,
#          '갈수록': 2,
#          '식품': 20,
#          '사과': 3,
#          '농협': 24,
#          '하나로마트': 13,
#          '의견': 5,
#          '어제': 1,
#          '위': 66,
#          '여부': 5,
#          '공급': 13,
#          '오늘': 12,
#          '할인': 32,
#          '본격': 5,
#          '천일염': 2,
#          '평년': 1,
#          '이상': 19,
#          '총력전': 1,
#          '장다리': 7,
#          '음식': 17,
#          '문화': 8,
#          '거리': 24,
#          '외식': 34,
#          '상인': 40,
#          '직접': 15,
#          '방안': 26,
#          '모색': 10,
#          '강경': 1,
#          '산업': 9,
#          '통상': 3,
#          '자원부': 1,
#          '범': 2,
#          '부처': 3,
#          '석유': 1,
#          '단': 7,
#          '발족': 1,
#          '첫': 6,
#          '우유': 11,
#          '태스크포스': 2,
#          '커피': 8,
#          '개': 56,
#          '집중': 3,
#          '주필': 6,
#          '협조': 2,
#          '요청': 7,
#          '업주': 3,
#          '인건비': 14,
#          '모든': 18,
#          '제반': 3,
#          '애로': 12,
#          '건의': 1,
#          '사항': 13,
#          '청취': 6,
#          '정점': 3,
#          '기록': 16,
#          '대통령실': 1,
#          '처음': 11,
#          '한식': 1,
#          '연': 10,
#          '자영': 8,
#          '업자': 8,
#          '만큼': 12,
#          '원금': 3,
#          '환수': 1,
#          '환영': 1,
#          '지속': 41,
#          '신인': 1,
#          '며': 72,
#          '거듭': 2,
#          '불가': 1,
#          '입장': 9,
#          '추': 2,
#          '부총리': 2,
#          '취재': 3,
#          '결과': 8,
#          '건축물': 1,
#          '대장': 1,
#          '토지대장': 1,
#          '행정': 6,
#          '시스템': 1,
#          '정씨': 1,
#          '일가': 1,
#          '자원': 3,
#          '순환': 4,
#          '센터': 35,
#          '추석': 98,
#          '연휴': 44,
#          '배출': 2,
#          '쓰레기': 8,
#          '처리': 3,
#          '소비': 21,
#          '상공': 31,
#          '일회용품': 1,
#          '사용제한': 1,
#          '시행': 15,
#          '플라스틱': 1,
#          '재활용': 2,
#          '정리': 1,
#          '그간': 4,
#          '규제': 5,
#          '지수': 25,
#          '발표': 12,
#          '보고': 11,
#          '전과': 3,
#          '비교': 8,
#          '개월': 12,
#          '연속': 7,
#          '중동': 1,
#          '만난': 11,
#          '임모': 1,
#          '슬슬': 1,
#          '품목': 31,
#          '보통': 21,
#          '번': 5,
#          '여러': 7,
#          '종류': 2,
#          '김치': 3,
#          '편': 5,
#          '편의점': 6,
#          '하이트진로': 2,
#          '내달': 5,
#          '발': 2,
#          '최소': 5,
#          '선': 6,
#          '률': 12,
#          '결정': 63,
#          '수원역': 5,
#          '로데오거리': 1,
#          '차': 18,
#          '퇴진': 1,
#          '진보': 1,
#          '중도': 1,
#          '보수': 2,
#          '연대': 3,
#          '경제성장률': 1,
#          '폭등': 13,
#          '가계부채': 2,
#          '폭증': 1,
#          '실질': 18,
#          '세': 44,
#          '주부': 8,
#          '김': 33,
#          '모씨': 9,
#          '때': 36,
#          '사실': 12,
#          '절': 3,
#          '절반': 4,
#          '고춧가루': 2,
#          '소금': 3,
#          '예년': 2,
#          '광주': 2,
#          '광역시': 1,
#          '에스토니아': 2,
#          '국토': 2,
#          '면적': 4,
#          '국제': 16,
#          '정세': 3,
#          '산': 1,
#          '목재': 1,
#          '경쟁력': 2,
#          '중': 23,
#          '별관': 1,
#          '가족': 7,
#          '다문화': 1,
#          '과동': 1,
#          '건립': 3,
#          '억': 1,
#          '책정': 3,
#          '원재': 1,
#          '룟값': 1,
#          '따위': 2,
#          '여파': 10,
#          '약': 5,
#          '신선': 5,
#          '온라인': 8,
#          '구매': 14,
#          '티몬': 1,
#          '카테고리': 1,
#          '농수산': 4,
#          '홈쇼핑': 4,
#          '아카데미': 2,
#          '실시': 6,
#          '입점': 2,
#          '희망': 4,
#          '중소기업': 3,
#          '기획전': 1,
#          '고객': 6,
#          '상품': 13,
#          '교육': 9,
#          '도청': 10,
#          '국회': 4,
#          '위원회': 12,
#          '국정감사': 2,
#          '김희국': 1,
#          '국민': 36,
#          '힘': 22,
#          '의원': 21,
#          '서울시': 5,
#          '민간': 7,
#          '사업자': 5,
#          '협상': 1,
#          '기획재정부': 4,
#          '기재부': 2,
#          '문': 4,
#          '인계동': 5,
#          '곽': 2,
#          '문수': 1,
#          '무영': 1,
#          '쌈밥': 1,
#          '정식': 2,
#          '대표': 24,
#          '가스': 5,
#          '전체': 8,
#          '공인': 70,
#          '중개사': 1,
#          '저': 3,
#          '사람': 9,
#          '거': 13,
#          '개도': 1,
#          '안': 15,
#          '등기부': 1,
#          '등본': 1,
#          '감수': 1,
#          '전제': 2,
#          '생략': 1,
#          '발언': 2,
#          '일': 42,
#          '대상': 22,
#          '소독': 9,
#          '방역': 9,
#          '청': 15,
#          '수원': 114,
#          '임종인': 1,
#          '활성화': 64,
#          '안정화': 11,
#          '도모': 7,
#          '개소': 14,
#          '국립': 3,
#          '관리원': 2,
#          '기지원': 2,
#          '사무소': 2,
#          '불확실': 1,
#          '대처': 1,
#          '긍정': 1,
#          '관점': 1,
#          '정치': 7,
#          '기후': 3,
#          '현실': 21,
#          '환경': 15,
#          '동행': 7,
#          '카드': 10,
#          '추진': 30,
#          '수단': 1,
#          '분담': 1,
#          '도내': 7,
#          '도시': 34,
#          '성남': 1,
#          '용인': 7,
#          '신분당선': 5,
#          '제외': 12,
#          '점도': 1,
#          '서민': 47,
#          '가장': 19,
#          '기본': 4,
#          '밥상': 9,
#          '걱정': 9,
#          '중심': 23,
#          '쌀': 5,
#          '배신': 1,
#          '흉': 1,
#          '동시': 20,
#          '이중': 1,
#          '과': 5,
#          '쌀값': 1,
#          '윤재옥': 2,
#          '원내대표': 4,
#          '회의': 26,
#          '본관': 2,
#          '호': 5,
#          '관계': 4,
#          '산업부': 1,
#          '자유': 1,
#          '구역': 12,
#          '출범': 1,
#          '주년': 3,
#          '대중교통': 8,
#          '적자': 5,
#          '감소': 3,
#          '탄소': 2,
#          '감': 2,
#          '명': 19,
#          '이상은': 1,
#          '무제한': 1,
#          '정기': 8,
#          '인천': 13,
#          '계': 4,
#          '적용': 16,
#          '공항철도': 3,
#          '심야버스': 3,
#          '생활권': 4,
#          '공유': 4,
#          '편의': 3,
#          '부진': 5,
#          '대비': 22,
#          '광주시': 3,
#          '송정': 3,
#          '강원': 3,
#          '도산': 1,
#          '뉴시스': 5,
#          '유': 3,
#          '고민': 7,
#          '배춧값': 1,
#          '비롯': 9,
#          '관내': 6,
#          '홍보': 4,
#          '인쇄업체': 1,
#          '유영준': 1,
#          '조만간': 1,
#          '출시': 1,
#          '박성수': 1,
#          '탓': 10,
#          '미래': 2,
#          '저축': 1,
#          '학생': 5,
#          '인터뷰': 7,
#          '이세현': 1,
#          '전반': 21,
#          '빠듯': 1,
#          '살림살이': 2,
#          '고려': 37,
#          '교통비': 6,
#          '절실': 2,
#          '목소리': 10,
#          '내': 22,
#          '현황': 4,
#          '행정안전부': 2,
#          '홈페이지': 23,
#          '확인': 21,
#          '기지역': 6,
#          '번지': 2,
#          '단일': 1,
#          '기초': 6,
#          '석': 1,
#          '배정': 1,
#          '총선': 1,
#          '의정부시': 1,
#          '북부': 3,
#          '특별자치도': 1,
#          '설치': 9,
#          '현안': 4,
#          '때문': 22,
#          '얘기': 3,
#          '엄마': 2,
#          '만': 7,
#          '주민': 15,
#          '분야': 10,
#          '참여': 21,
#          '주최': 3,
#          '측': 4,
#          '가치': 3,
#          '출하': 1,
#          '프로그램': 1,
#          '전환': 3,
#          '최저임금': 75,
#          '적정': 2,
#          '활동': 9,
#          '와중': 1,
#          '듯': 2,
#          '줄줄이': 5,
#          '사흘': 1,
#          '전': 45,
#          '우윳값': 1,
#          '운': 1,
#          '캔': 1,
#          '맥주': 3,
#          '평소': 2,
#          '거기': 1,
#          '명절': 48,
#          '상차림': 3,
#          '온': 7,
#          '북적': 2,
#          '정치권': 1,
#          '시선': 2,
#          '환율': 14,
#          '직장인': 5,
#          '박모': 1,
#          '관심': 2,
#          '주머니': 1,
#          '현': 2,
#          '감정': 1,
#          '귀향': 3,
#          '길': 6,
#          '나선': 4,
#          '아침': 9,
#          '라디오': 3,
#          '방송': 3,
#          '출연': 9,
#          '의장': 13,
#          '맞이': 11,
#          '의정': 5,
#          '재래시장': 3,
#          '차례상': 10,
#          '주제': 4,
#          '물씬': 1,
#          '첫날': 6,
#          '전통': 60,
#          '부모님': 1,
#          '연로': 1,
#          '과일': 11,
#          '세대': 9,
#          '패턴': 1,
#          '변화': 6,
#          '인구': 7,
#          '유출': 1,
#          '팔달문': 4,
#          '로터리': 1,
#          '실률': 1,
#          '소규모': 1,
#          '상가': 6,
#          '중대': 3,
#          '집합': 1,
#          '얼른': 1,
#          '전인': 1,
#          '낮': 2,
#          '지동': 7,
#          '우려': 13,
#          '건강': 3,
#          '보험': 5,
#          '적립금': 1,
#          '육박': 3,
#          '수수': 1,
#          '실': 16,
#          '촬영': 2,
#          '수술실': 1,
#          '폐쇄회': 2,
#          '의무': 1,
#          '마케팅': 2,
#          '기획': 1,
#          '이마트': 3,
#          '햅쌀': 1,
#          '화성시': 48,
#          '일부': 11,
#          '이용': 4,
#          '회': 151,
#          '용기': 2,
#          '살피': 1,
#          '성수': 20,
#          '품': 27,
#          '계획': 10,
#          '인파': 1,
#          '이보': 1,
#          '앞서': 7,
#          '의회': 55,
#          '단도': 1,
#          '이번': 45,
#          '소상': 69,
#          '경청': 7,
#          '김정호': 11,
#          '가파른': 10,
#          '위축': 30,
#          '물리': 9,
#          '도의': 12,
#          '촉진': 5,
#          '캠페인': 24,
#          '슬로건': 7,
#          '안전': 6,
#          '김흥': 2,
#          '아주대': 7,
#          '공공정책': 3,
#          '대학원': 3,
#          '나': 6,
#          '청수': 1,
#          '동문회': 1,
#          '앞줄': 1,
#          '오른쪽': 3,
#          '전달': 13,
#          '학교': 6,
#          '매탄': 5,
#          '일원': 4,
#          '전개': 5,
#          '강남': 1,
#          '분당구': 2,
#          '사': 8,
#          '측은': 6,
#          '개통': 1,
#          '국토교통부': 3,
#          '협약': 6,
#          '당시': 2,
#          '운임': 1,
#          '오전': 51,
#          '투입': 2,
#          '저온': 1,
#          '피해': 12,
#          '생산': 1,
#          '량': 2,
#          '폭': 27,
#          '세트': 5,
#          '상임': 1,
#          '위원장': 11,
#          '시정': 3,
#          '연구원': 5,
#          '관해': 1,
#          '소통': 3,
#          '공통': 2,
#          '최소한': 3,
#          '보아': 1,
#          '매년': 6,
#          '금': 10,
#          '공무원': 6,
#          '원산지': 17,
#          '표시': 17,
#          '생산자': 4,
#          '시차': 1,
#          '영향': 51,
#          '차려': 1,
#          '시름': 2,
#          '거주': 8,
#          '채소': 15,
#          '군부': 2,
#          '위문': 8,
#          '보병': 2,
#          '사단': 2,
#          '체험': 7,
#          '회복': 11,
#          '새마을': 2,
#          '광명': 4,
#          '안성시': 7,
#          '업무': 3,
#          '기호일보': 6,
#          '여': 11,
#          '신문': 11,
#          '노사': 53,
#          '민정': 49,
#          '협의': 78,
#          '상': 148,
#          '승률': 148,
#          '국내': 30,
#          '재정': 54,
#          '두루': 1,
#          '검토': 24,
#          '생활임금': 90,
#          '은': 44,
#          '걸음': 15,
#          '인간': 2,
#          '다운': 1,
#          '도입': 30,
#          '노동자': 9,
#          '권리': 1,
#          '존중': 1,
#          '노': 1,
#          '노동계': 1,
#          '고용주': 1,
#          '민': 29,
#          '정': 10,
#          '지방정부': 2,
#          '대상자': 11,
#          '출자': 6,
#          '소속': 5,
#          '존엄성': 1,
#          '유지': 10,
#          '주거': 9,
#          '교육비': 1,
#          '법정': 1,
#          '지급': 20,
#          '제도로': 1,
#          '지방자치단체': 3,
#          '조례': 3,
#          '스포츠서울': 5,
#          '좌승': 5,
#          '훈기': 5,
#          '정협': 3,
#          '설명': 7,
#          '민족': 3,
#          '최대': 15,
#          '용품': 5,
#          '정보': 9,
#          '전국': 14,
#          '경제위기': 5,
#          '도민': 5,
#          '탐방': 1,
#          '일정': 2,
#          '예정': 35,
#          '배': 15,
#          '규모': 4,
#          '선뜻': 1,
#          '손길': 3,
#          '가지': 3,
#          '토로': 3,
#          '총': 11,
#          '주택': 46,
#          '오산시': 4,
#          '사비': 17,
#          '집계': 2,
#          '트램': 2,
#          '구간': 2,
#          ...})

# %%
word_count = dict()

for tag, counts in count.most_common(80):
    if(len(str(tag))>1):
        word_count[tag] = counts
        print("%s : %d" % (tag, counts))
# Out:
# 물가 : 1142
# 수원시 : 1131
# 가격 : 330
# 상승 : 327
# 경기 : 289
# 경기도 : 246
# 시장 : 226
# 지역 : 214
# 경제 : 185
# 안정 : 181
# 인상 : 178
# 소비자 : 158
# 승률 : 148
# 위해 : 144
# 상황 : 132
# 침체 : 116
# 노인 : 116
# 수원 : 114
# 지난 : 109
# 추석 : 98
# 어려움 : 93
# 생활 : 90
# 생활임금 : 90
# 가구 : 90
# 대책 : 89
# 평균 : 88
# 금리 : 87
# 이재준 : 85
# 시민 : 83
# 최근 : 83
# 지원 : 80
# 서비스 : 79
# 협의 : 78
# 최저임금 : 75
# 관계자 : 72
# 부담 : 71
# 방문 : 70
# 반영 : 70
# 공인 : 70
# 행사 : 69
# 소상 : 69
# 관리 : 68
# 민생 : 67
# 동향 : 66
# 오후 : 64
# 기자 : 64
# 제공 : 64
# 활성화 : 64
# 정부 : 63
# 결정 : 63
# 팔달구 : 62
# 여건 : 62
# 임금 : 60
# 전통 : 60
# 운영 : 59
# 내년 : 58
# 급식 : 57
# 올해 : 56
# 의회 : 55
# 단가 : 55
# 사진 : 54

# %%
mask_path = 'cloud.png'
cloud_mask = np.array(Image.open(mask_path)) # 구름 모양 워드 클라우드 생성

wc = WordCloud(font_path, background_color='white', width=800, height=600, mask=cloud_mask, colormap='inferno')
cloud=wc.generate_from_frequencies(word_count)

plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()
